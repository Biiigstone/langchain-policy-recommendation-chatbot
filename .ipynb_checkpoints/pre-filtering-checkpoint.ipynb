# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Pre-filtering with Chroma DB to avoid GIGO.


# 1) 메타데이터는 어떻게 사용되는걸까?
# indexing을 하며 계속 의문점이 들었다. 대체 메타데이터를 어떻게 활용하는거지? 머릿속에 든 의문점을 하나씩 적어보자.
# 1. 기본적으로 프롬프팅 시 메타데이터를 포함하여 프롬프팅하므로, LLM은 메타데이터를 참고하긴 한다.
# 2. 예를 들어, 연도 정보가 중요한 상황일 때, LLM은 충분히 똑똑하므로 현재 시간과 연도 메타데이터를 참고하여 자체적으로 연도가 지난 데이터를 참고하지 않는다.
# 3. 즉 r 과정을 통해 가져온 정보가 정확하지 않다면.. 예를 들어 k가 3일 때, 3개 청크의 메타데이터 전부가 2020년의 정보라면, LLM은 지원 가능한 정책이 없다 등으로 답변할 것이다.
# 4. 여기서 pre-filtering의 중요성이 대두된다. GIGO를 피하기 위해.

# 2) R의 근본적 한계
# 1. r은 벡터 DB가 지원하는 단순 유사도 검색을 통해 그 결과를 가져온다.
# 2. 즉, 개발자가 필터링 조건을 걸지 않는 이상, 질문과 가장 유사한 벡터를 가져온다. 그것의 메타데이터가 어떻든지 상관하지 않고.
# 3. 예를 들어 '30대 남성이 지원 가능한 미술 정책 검색해줘' 라는 질문을 받는다면, DB에 존재하는 모든 문서들.. 00년 부터 25년까지.. 단순 저 질문 자체의 벡터와 가장 유사한 것들을 가져온다는 말이다.
# 4. 어쩌면 25년 정책으로 청크들이 구성될 수도 있겠지만, 항상 이를 보장하지는 않는다는 것이 문제이다.
# 5. 따라서 이 바보같지만 착한 리트리버를 위해 우리가 필터링을 해 주어야 한다는 것이다(pre-filtering)
# 6. 다행히도 벡터DB들은 필터링 쿼리를 제공하므로, 우리는 정규식이나 코드 또는 sLLM 등을 통해 사용자 질문을 기반으로 벡터 쿼리를 잘 생성하기만 하면 된다.

# %%
# Chroma DB 세팅하기
# https://docs.trychroma.com/docs/querying-collections/metadata-filtering

# Chroma는 두 가지 유형의 필터를 제공.
# 원하는 조건을 dict 형태로 제공한다.

# 메타데이터 필터: Collection.query() 또는 Collection.get()에서 where 절을 사용하여 메타데이터를 기반으로 문서를 필터링
# 문서 필터: Collection.query() 또는 Collection.get()에서 where_document를 사용하여 문서 내용을 기반으로 필터링

# 필터 연산자(예: $eq, $gt)등을 사용하여 명시적인 필터링이 가능하다.
# 이때, 메타데이터의 타입을 구분하여 처리하므로, 숫자 비교 연산자를 올바르게 사용하려면, 메타 데이터의 값도 숫자(int, float) 타입이어야 한다.
# 따라서 메타 데이터 필터링을 고려한다면 단순 문자열 코딩은 피해야 한다.
# 날짜도 마찬가지.

# 5.1 이상의 값
# results = collection.query(
#     query_texts=["검색할 문서입니다"],
#     n_results=2,
#     where={"rating": {"$gte": 5.1}}
# )

# 크로마 쿼리 작성도 llm이 잘하네!

# %%
# 따라서 이전의 document from csv 함수를 좀 수정하자
# 단순 문자열 필드 -> 숫자 필드로. 날짜 또한 timestamp보단 YYMMDD의 숫자로.

import csv
from langchain_core.documents import Document
from datetime import datetime

def create_documents_from_csv(csv_file_path: str) -> list[Document]:
    """
    CSV 파일에서 정책 정보를 읽어와 LangChain의 Document 객체 리스트로 변환합니다.
    (날짜 처리: YYYYMMDD 정수 변환 방식 적용)
    """
    
    documents = []
    
    try:
        with open(csv_file_path, mode='r', encoding='utf-8') as csvfile:
            reader = csv.DictReader(csvfile)
            
            for row in reader:
                # 1. page_content 구성
                page_content = f"""
정책명: {row.get('plcyNm', '정보 없음')}
정책 설명: {row.get('plcyExplnCn', '정보 없음')}
지원 내용: {row.get('plcySprtCn', '정보 없음')}
신청 자격: {row.get('addAplyQlfcCndCn', '정보 없음')}
"""
                # 2. metadata 기본 구성
                metadata = {
                    "policy_id": row.get('plcyNo'),
                    "policy_name": row.get('plcyNm'),
                    "main_department": row.get('sprvsnInstCdNm'),
                    "operating_department": row.get('operInstCdNm'),
                    "category_large": row.get('lclsfNm'),
                    "category_medium": row.get('mclsfNm'),
                }

                # 3. 숫자 필드 타입 변환
                numeric_fields = {
                    "min_age": row.get('sprtTrgtMinAge'),
                    "max_age": row.get('sprtTrgtMaxAge'),
                }
                for key, value in numeric_fields.items():
                    if value is not None and value.strip() != '':
                        try:
                            metadata[key] = int(value)
                        except ValueError:
                            metadata[key] = value

                # 4. 💡 날짜 필드를 YYYYMMDD 정수로 변환
                application_period_str = row.get('aplyYmd', '')
                if ' ~ ' in application_period_str:
                    try:
                        start_date_str, end_date_str = application_period_str.split(' ~ ')
                        
                        # 하이픈(-)을 제거하고 정수로 변환 (예: "2025-07-21" -> 20250721)
                        metadata['start_date_int'] = int(start_date_str.strip().replace('-', ''))
                        metadata['end_date_int'] = int(end_date_str.strip().replace('-', ''))
                        
                        metadata['application_period_str'] = application_period_str # 원본 문자열도 저장
                    except (ValueError, TypeError):
                        metadata['application_period_raw'] = application_period_str
                else:
                     metadata['application_period_raw'] = application_period_str

                # 5. 최종 Document 생성
                cleaned_metadata = {k: v for k, v in metadata.items() if v is not None and v != ''}
                documents.append(Document(page_content=page_content.strip(), metadata=cleaned_metadata))
                
    except FileNotFoundError:
        print(f"오류: '{csv_file_path}' 파일을 찾을 수 없습니다.")
    except Exception as e:
        print(f"파일을 읽는 중 오류가 발생했습니다: {e}")
        
    return documents

# %%
# 테스트
data = create_documents_from_csv("./policy_data.csv")
# data = create_documents_from_csv("./test.csv")
data
# Out:
# [Document(metadata={'policy_name': '웹툰캠퍼스 운영 및 인력 양성', 'main_department': '문화콘텐츠과', 'operating_department': '재단법인대구디지털혁신진흥원', 'category_large': '복지문화', 'category_medium': '예술인지원', 'min_age': 0, 'max_age': 0, 'start_date_int': 20250501, 'end_date_int': 20250530, 'application_period_str': '20250501 ~ 20250530'}, page_content='정책명: 웹툰캠퍼스 운영 및 인력 양성\n정책 설명: - 현장 실무형 전문인력 프로그램을 통한 글로벌 웹툰작가 양성\n- 웹툰 창작 및 제작 역량 강화, 산업 활성화 지원\n지원 내용: - 지역 웹툰작가 양성을 위한 교육 및 프로그램 운영\n- 교육생 월 창작지원금 및 원고료 지원 등\n신청 자격:'),
#  Document(metadata={'policy_name': '학예사 인턴 운영', 'main_department': '도립미술관', 'operating_department': '도립미술관', 'category_large': '복지문화', 'category_medium': '예술인지원', 'min_age': 18, 'max_age': 39}, page_content="정책명: 학예사 인턴 운영\n정책 설명: 도내 전문 학예인력 양성 및 시각예술 분야 청년 일자리 창출\n지원 내용: '박물관·미술관 학예사 자격증’ 취득을 위한 미술관 실습 기회 제공 및 시각예술 분야 청년 학예인력 양성\n신청 자격: (필수) 만 18세 이상 만 39세 이하의 청년\n1. 고등교육법에 의해 설치된 4년제 정규대학의 관련분야 학사 졸업자 \n2. 고등교육법에 의해 설치된 4년제 정규대학의 관련분야 석사 졸업자 또는 수료자\n3. 준학예사 자격증을 취득한 자 \n※ 필수사항에 해당하면서 1,2,3 각 호에 1개 이상 해당자\n※ 관련 분야\n- 미술이론(미술사학과, 미학과, 예술학 등) 관련학과, 미술실기 및 디자인 관련학과(시각, 산업, 영상, 공간 디자인 등) 등 \n\n(가점사항)\n장애인, 전북지역 대학(원) 졸업자, 공고일 이전 전북특별자치도 거주자"),
#  Document(metadata={'policy_name': '전북청년 2025 (전북청년 미술 운영)', 'main_department': '도립미술관', 'operating_department': '도립미술관', 'category_large': '복지문화', 'category_medium': '예술인지원', 'min_age': 18, 'max_age': 39, 'start_date_int': 20241007, 'end_date_int': 20241018, 'application_period_str': '20241007 ~ 20241018'}, page_content='정책명: 전북청년 2025 (전북청년 미술 운영)\n정책 설명: 전북 청년미술가의 안정적 창작활동을 위한 환경제공 및 역량 강화를 위한 전문가들과의 교류 확대\n지원 내용:  전북 청년 미술가 창작진흥을 위한 기획전시 및 물적/인적 네트워크 구축, 평론가 1:1 매칭 등 추진\n신청 자격: (공통) 1,2번이 모두 해당되면서, (선택) 1개의 항목이 해당된 자 \n(공통)\n1. 공고년도 기준 39세 이하 (1985년 1월 1일 이후 출생)\n2. 개인전 3회 이상 개최한 자(아트페어 부스전, 갤러리 카페 등 제외) \n(선택) 1개의 항목만 해당되어도 조건 충족 \n① 공고일 기준 전라북도에 주민등록을 두고 3년 이상 \n   거주하면서 전라북도에서 작품활동을 하는 사람\n② 공고일 기준 전라북도에 3년 이상 작업실을 두고 \n   전라북도에서 작품활동을 하는 사람 \n③ 전라북도에서 출생하였거나 12년 이상 주민등록을 두고 거주한 \n   자로서 전라북도외(해외포함)에서 작품활동을 하는 사람\n ※ 공고일 기준 최근 3년 이내 활동 증빙자료 제출'),
#  Document(metadata={'policy_name': '제주특별자치도 공공기관 통합채용', 'main_department': '특별자치행정국', 'operating_department': '특별자치행정국', 'category_large': '일자리', 'category_medium': '취업', 'min_age': 0, 'max_age': 0}, page_content='정책명: 제주특별자치도 공공기관 통합채용\n정책 설명: ❍ 제주도 내 공공기관 채용과정의 공정성·투명성 확보 및 도민 신뢰 제고를 위해 공공기관 통합채용 추진 (연 3회 공공기관 통합채용 공동실시) \n지원 내용: ❍ 제주도 내 공공기관 채용정보 통합제공으로 접근성 제고 및 공정한 채용문화 확산\n신청 자격: 제주특별자치도 공공기관 통합채용 공고문 참조'),
#  Document(metadata={'policy_name': '제3차 대구광역시 청년정책 기본계획 수립', 'main_department': '대구광역시', 'operating_department': '재단법인대구정책연구원', 'category_large': '참여권리', 'category_medium': '정책인프라구축', 'min_age': 19, 'max_age': 39}, page_content='정책명: 제3차 대구광역시 청년정책 기본계획 수립\n정책 설명: 지역 청년의 삶 전반을 고려한 중장기 전략인「제3차 대구광역시 청년정책 기본계획」수립으로 다양한 정책 발굴을 통해 대구 청년의 권익증진과 발전에 기여\n지원 내용: - 청년정책 동향, 대구시 청년 현황·실태조사 및 정책현황·평가\n- 제3차 기본계획 방향, 추진목표, 부문별 정책 과제 발굴\n- 청년지원 거버넌스 구축, 정책 추진을 위한 재원 조달방안 등\n신청 자격:'),
#  Document(metadata={'policy_name': '업사이클센터 지원사업', 'main_department': '대구광역시', 'category_large': '일자리', 'category_medium': '창업', 'min_age': 19, 'max_age': 39}, page_content='정책명: 업사이클센터 지원사업\n정책 설명: 업사이클관련 청년창업기업 등 성장지원, 창업공유공간 대여 \n지원 내용: - 업사이클센터 입주기업 및 청년창업기업 성장지원\n- 업사이클센터 청년창업 공유공간 조성 및 운영\n- 디자인 리메이커 팩토리(메이커 스페이스) 운영\n- 업사이클 입주기업 및 창업기업 역량 강화\n신청 자격:'),
#  Document(metadata={'policy_name': '제주 청년의 날', 'main_department': '청년정책담당관', 'category_large': '복지문화', 'category_medium': '문화활동', 'min_age': 0, 'max_age': 0}, page_content="정책명: 제주 청년의 날\n정책 설명: 법정기념일 '청년의 날' 기념 프로그램 운영\n지원 내용: 법정기념일인 ‘청년의 날’ 기념식 및 「청년기본법」에 따라 청년의 날로부터 1주간 청년 주간으로 운영하여 청년이 기획·참여하는 프로그램 운영으로 청년 이슈 공유와 청년 발전의 중요성을 알리는 행사 추진\n신청 자격:"),
#  Document(metadata={'policy_name': '청년 체인지 메이커 아카데미 운영', 'main_department': '청년정책담당관', 'category_large': '교육', 'category_medium': '미래역량강화', 'min_age': 0, 'max_age': 0}, page_content='정책명: 청년 체인지 메이커 아카데미 운영\n정책 설명: 생애전환기 진로 설계 등으로 고민하는 청년에게 전문가 및 명사의 강연 참여기회 제공\n지원 내용: 청년들을 대상으로 취,창업 역량강화 프로그램 및 문화예술 강연 등 다양한 주제로 편성한 정기적 강연 프로그램 운영\n신청 자격:'),
#  Document(metadata={'policy_name': '청년농업인 영농문제 해결 스터디그룹', 'main_department': '농업기술원', 'category_large': '교육', 'category_medium': '미래역량강화', 'min_age': 19, 'max_age': 45, 'start_date_int': 20250313, 'end_date_int': 20250321, 'application_period_str': '20250313 ~ 20250321'}, page_content='정책명: 청년농업인 영농문제 해결 스터디그룹\n정책 설명: 청년농업인 영농 스터디그룹 운영으로 영농문제 해결 및 농촌자원활용 새 소득 사업 발굴을 통한 청년농업인 경쟁력 강화\n지원 내용: - 영농문제 해결 및 농촌자원 활용 새 소득 사업 발굴을 위한 스터디그룹 활동지원\n- 청년농업인 영농기술 습득 및 사업발굴을 통한 농가 소득화 지원 \n신청 자격:'),
#  Document(metadata={'policy_name': '대학생 봉사활동 활성화', 'main_department': '울산광역시', 'category_large': '참여권리,참여권리', 'category_medium': '청년참여,정책인프라구축', 'min_age': 19, 'max_age': 39}, page_content="정책명: 대학생 봉사활동 활성화\n정책 설명: 청년들을 대상으로 자원봉사활동을 지원하여 이타심과 공동체성을 배양하고 더불어 사는 지역사회 조성에 기여\n지원 내용:  \n○ 사업기간 : '25. 1. ~ 12.\n\n○ 지원대상 : 대학생봉사단('24년 19기 봉사단 922명)\n\n○ 지원방법 : 시 자원봉사센터 '대학생 봉사활동 활성화' 사업비 지원\n\n○ 주관기관 : (사)울산광역시자원봉사센터\n신청 자격:"),
#  Document(metadata={'policy_name': '청년활동경험지원사업', 'main_department': '울산광역시', 'category_large': '참여권리,참여권리', 'category_medium': '청년참여,정책인프라구축', 'min_age': 19, 'max_age': 39}, page_content="정책명: 청년활동경험지원사업\n정책 설명: 민간 청년단체 발굴·지원으로 청년 커뮤니티 활성화 등 자발적 진로탐색 도모 및 청년의 지역 정착 기반 마련\n지원 내용:  \n○ 사업기간 : '25. 1. ~ 12.\n\n○ 대 상 : 울산에서 거주하거나 활동 중인 3인 이상 청년단체\n\n○ 사업규모 : 6개팀\n\n○ 주요내용 : 청년단체 발굴 및 활동비(500만원), 교류, 활동 홍보 지원\n신청 자격:"),
#  Document(metadata={'policy_name': '청년성장지원사업', 'main_department': '울산광역시', 'category_large': '참여권리,참여권리', 'category_medium': '청년참여,정책인프라구축', 'min_age': 19, 'max_age': 39}, page_content="정책명: 청년성장지원사업\n정책 설명: 청년의 진로탐색, 삶의 안정을 위한 체계적인 교육 제공으로 청년정책에 대한 청년의 관심도 제고 및 청년커뮤니티 활성화\n지원 내용: ○ 사업기간 : '25. 1. ~ 12.\n\n○ 주요사업 : 청년들의 성장 지원을 위한 교육, 교류회 등 진행\n\n○ 사업내용\n- 강의교육사업 : 취창업,·진로·금융·마음건강 등 멘토 초청 강연\n- 정책배움터 : 청년정책의 이해, 우수사례, 정책제안 방법 등 교육\n- 활동교류회 : 연간 성과공유 및 교류로 청년 네트워크 활성화 \n신청 자격:"),
#  Document(metadata={'policy_name': '청년이 만드는 치안정책 플랫폼‘자치경찰 서포터즈’', 'main_department': '울산광역시', 'category_large': '참여권리,참여권리', 'category_medium': '청년참여,정책인프라구축', 'min_age': 19, 'max_age': 34}, page_content='정책명: 청년이 만드는 치안정책 플랫폼‘자치경찰 서포터즈’\n정책 설명: 청년들이 주도적으로 자치경찰 정책들을 홍보하고, 다각적인 시각에서 치안 아이디어를 발굴할 수 있는 플랫폼(Platform)을 운영하고자 함\n지원 내용:  \n○ 사업기간 : ‘25. 8. ~ ‘26. 5.(10개월)\n\n○ 구    성 : 관내 대학에 재학 중인 청년 10명(19세~39세)\n \n○ 역    할 : 정책홍보, 영상 제작, 정책 아이디어 발굴, 캠페인 활동\n \n○ 운영방식 : 팀 회의(月 2회) 및 콘텐츠 제작 발표회(月 1회) 정기 운영\n    - 팀 회의 : 콘텐츠 주제 선정, 팀원 간 역할분배, 홍보계획 사전검토\n    - 콘텐츠 제작 발표회 : 월간 콘텐츠 제작물 발표 및 온·오프라인 게시\n \n○ 사 업 비 : 5백만원  ※ 디자인 제작 플랫폼 유료 이용권, 행사운영비 \n \n신청 자격:'),
#  Document(metadata={'policy_name': '구·군 통합 협의체 하이-청년 운영', 'main_department': '울산광역시', 'category_large': '참여권리', 'category_medium': '정책인프라구축', 'min_age': 19, 'max_age': 39}, page_content='정책명: 구·군 통합 협의체 하이-청년 운영\n정책 설명: 중앙-시 청년정책을 기초 청년지원센터로의 전달 채널과 협력 네트워킹을 위한 가교로서 상시 협력 체계 마련 필요\n지원 내용: ○ 사업기간 : ‘25. 1. ~ 12.\n \n○ 추진방향 : 목적 기반 협의체 운영으로 광역-기초센터 상생 협력\n    - (정기 간담회) 청년정책 현안 논의 및 협력 사업 발굴\n    - (합동사업 추진) 구·군의 관광 인프라 등을 활용한 합동 사업 진행\n    - (종사자 역량 강화) 번아웃 방지 등을 위한 교류 및 역량 강화 교육 진행\n \n○ 주요내용\n    - 6개 기초청년센터를 중심으로 울산시·구·군 청년정책 담당자들과 정기적인 소통 채널을 구축하여, 정보 공유 및 청년정책 개발에 대한 협력 강화\n      (정기 간담회, 연계사업 추진, 종사자 역량 강화 교육, 교류 네트워킹 등)\n    - 구성인원 : 20명 정도(시·구·군 청년정책팀장 및 담당자, 청년센터장 등)\n \n○ 수행기관 : 울산창조경제혁신센터\n신청 자격:'),
#  Document(metadata={'policy_name': '청년상담소(고민점빵) 운영', 'main_department': '울산광역시', 'operating_department': '(재)울산창조경제혁신센터', 'category_large': '참여권리', 'category_medium': '정책인프라구축', 'min_age': 19, 'max_age': 39}, page_content="정책명: 청년상담소(고민점빵) 운영\n정책 설명: 복잡하고 다양한 청년문제 대응하고, 유관기관과 연계하여 전문가와 1:1 매칭 상담으로 행복한 삶과 주체적으로 성장할 기회 제공\n지원 내용: ○ 사업기간 : '25. 2. ~ 12.\n\n○ 사업대상 : 울산시 거주 19세 ~ 39세 청년\n\n○ 주요사업 : 청년들의 고민을 분야별로 파악하여 전문가와 1:1 매칭 상담\n\n○ 사업내용 : 마음건강, 진단, 상담, 모니터링 등 심리안정 지원\n\n○ 수행기관 : 울산창조경제혁신센터\n신청 자격:"),
#  Document(metadata={'policy_name': '청년정책 홍보사업', 'main_department': '울산광역시', 'operating_department': '(재)울산창조경제혁신센터', 'category_large': '참여권리', 'category_medium': '정책인프라구축', 'min_age': 19, 'max_age': 39}, page_content="정책명: 청년정책 홍보사업\n정책 설명: 청년의 정책 체감도 향상 및 청년 참여 확대를 위한 다방면 홍보 추진\n지원 내용: ○ 사업기간 : '25. 1. ~ 12.\n\n○ 지원대상 : 19세 ~ 39세 울산 거주/재직/재학/활동 청년\n\n○ 주요내용 : SNS 및 소통커뮤니티 운영 등 온·오프라인 홍보\n   ① 청년정책 정보 수집 및 DB 구축\n       - 중앙부처/지자체 웹사이트, 공공데이터 포털 활용\n       - 관련 부서 담당자 협조 및 자료 요청\n       - 청년 정책 관련 연구자료, 보고서 분석\n    ② 정보 제공 채널 구축 및 운영\n       - SNS채널 운영(카카오톡, 인스타그램 등)\n       - 정기적인 소식지 발행 및 배포\n    \n○ 수행기관 : 울산창조경제혁신센터 (052-230-3435)\n신청 자격:"),
#  Document(metadata={'policy_name': '울산청년정책플랫폼 운영', 'main_department': '울산광역시', 'category_large': '참여권리', 'category_medium': '정책인프라구축', 'min_age': 19, 'max_age': 39}, page_content="정책명: 울산청년정책플랫폼 운영\n정책 설명: 부서별로 흩어진 청년정책 및 활동지원 사업, 커뮤니티 등을 모아낸 통합 정보 플랫폼 구축으로 원스톱 청년정보 제공 및 청년교류 활성화\n지원 내용:  \n○ 명 칭 : 울산청년정책플랫폼 유페이지(U-PAGE)\n※ 도메인 주소 : www.ulsan.go.kr/ulsanyouth / 운영개시 : '21. 12. 20\n\n○ 사업기간 : '25. 1. ~ 12.\n\n○ 주요메뉴 : 청년정책, 공모·지원사업, 울산청년지도, 고민점빵 등\n- 일자리, 주거, 복지, 등 청년과 관련된 497개 정보 수록\n \n신청 자격:"),
#  Document(metadata={'policy_name': '청년정책 제안 경연대회', 'main_department': '울산광역시', 'category_large': '참여권리', 'category_medium': '청년참여', 'min_age': 19, 'max_age': 39}, page_content="정책명: 청년정책 제안 경연대회\n정책 설명: 청년정책 수요 당사자인 청년들이 직접 청년정책을 발굴하여 청년의 정책 효능감 향상및 청년문제 해결을 위한 정책 참여 기회 제공\n지원 내용: ○ 시 기 : '25. 4. ~ 6.\n\n○ 참여대상 : 울산에 거주하거나 활동하는 19세 ~ 39세 청년\n\n○ 주요내용 : 정책 컨설팅을 통한 내실 있는 청년제안 발굴\n-분과별 토론, 정책의제 도출 및 구체화, 집중 멘토링\n-컨설팅을 통한 분과별 정책제안서 검토·작성\n\n○ 추진방법 : 제안서 접수 → 1차 심사 → 전문가 컨설팅 → 최종 심사\n ※ 팀구성 : 10개팀 30명 정도(팀당 3명 정도)\n신청 자격:"),
#  Document(metadata={'policy_name': '울산광역시 청년지원센터 운영', 'main_department': '울산광역시', 'category_large': '참여권리', 'category_medium': '청년참여', 'min_age': 19, 'max_age': 39}, page_content='정책명:
서관, 아파트 커뮤니티 공간 등 공공시설에 돌봄인력을 파견하여 탄력적인 돌봄을 제공\n    - 이웃애(愛) 돌봄 : 이웃이 돌봄의 주체로서 함께하는 육아품앗이로 공적 돌봄 틈새 보완 및 돌봄 공동체 문화 확산\n \n○ 수행기관 : 지역아동센터울산광역시지원단 / 울산광역시육아종합지원센터\n    - 해당참고사이트 : https://cafe.daum.net/togetherulsan / https://ulsan.childcare.go.kr/ccef/main.jsp\n신청 자격:'),
#  Document(metadata={'policy_name': '울산시립아이돌봄센터 운영', 'main_department': '울산광역시', 'operating_department': '재단법인울산광역시복지가족진흥사회서비스원', 'category_large': '복지문화', 'category_medium': '취약계층 및 금융지원', 'min_age': 0, 'max_age': 0}, page_content='정책명: 울산시립아이돌봄센터 운영\n정책 설명: 갑작스런 돌봄공백 발생 시 부모들이 안심하고 맡길 수 있는 안전한 시설에 대한 수요에 적극 부응하기 위함\n지원 내용: ○ 사업대상 : 긴급돌봄이 필요한 0~12세(를 돌보는 부모)\n\n○ 사업내용 : 365일 24시간 긴급돌봄 제공\n    - 일 최대 4시간, 월 최대 48시간\n \n○ 수행기관 : 울산광역시 복지가족진흥사회서비스원\n    - 참고사이트 : https://www.wfps.or.kr/webuser/page/main.html\n신청 자격:'),
#  Document(metadata={'policy_name': '대학생 학자금 대출이자 지원', 'main_department': '전북특별자치도', 'category_large': '교육', 'category_medium': '교육비지원', 'min_age': 0, 'max_age': 0, 'start_date_int': 20250301, 'end_date_int': 20250831, 'application_period_str': '20250301 ~ 20250831'}, page_content='정책명: 대학생 학자금 대출이자 지원\n정책 설명: 한국장학재단에서 대출받은 학자금에 대한 대출이자 지원\n지원 내용: 한국장학재단에서 대출받은 학자금에 대한 대출이자 지원\n신청 자격:'),
#  Document(metadata={'policy_name': '출향청년 채용 전주기업 취업지원', 'main_department': '전주시', 'category_large': '일자리', 'category_medium': '재직자', 'min_age': 18, 'max_age': 39, 'start_date_int': 20250604, 'end_date_int': 20250613, 'application_period_str': '20250604 ~ 20250613'}, page_content='정책명: 출향청년 채용 전주기업 취업지원\n정책 설명: 중소기업의 인력난을 해소하고 청년 고용의 기회를 확대하는 동시에 청년의 지역정착을 지원\n지원 내용: ○기업 : 청년 채용 1인당 월 100만원씩 12개월간 지원\n○청년 : 장려금 최대 900만원 지원(6, 12, 24개월 경과 시 각 300만원 지급)\n신청 자격: [기업]\n○전주시 소재 상시 근로자 3인 이상 고용보험 가입 기업으로 상시근로자 외 청년을 정규직으로 채용하고 월 급여액을 최저임금 이상 지급 가능한 기업\n○비영리법인 단체도 중소기업법상 중소기업 요건을 충족하는 경우 대상기업에 포함\n\n[청년]\n○18~39세 전주시 전입 청년으로 참여기업에서 6개월 미만 근무한 청년 자격요건을 충족한 자\n○자격요건에 기재된 주민등록상 주소지 기준을 충족하여야 함\n○고용보험에 가입 중인 자, 계약직, 프리랜서 등의 형태로 동일한 사업장에 재직하고 있는자, 세법에 따라 사업자등록을 한 자는 취업 중인 자로 봄'),
#  Document(metadata={'policy_name': '청년참여예산 운영', 'main_department': '전주시', 'category_large': '참여권리,참여권리', 'category_medium': '청년참여,정책인프라구축', 'min_age': 18, 'max_age': 39, 'start_date_int': 20250212, 'end_date_int': 20250228, 'application_period_str': '20250212 ~ 20250228'}, page_content='정책명: 청년참여예산 운영\n정책 설명: 일자리, 주거, 문화, 복지 등 청년에게 필요한 다양한 정책을 공모를 통해 선정‧지원\n지원 내용: 공모에 선정 된 단체당 10백만원 내외 사업비 지원\n신청 자격: 공고일 기준 구성원 50%이상이 전주시에 거주하고 있는 5인 이상의 단체로 대표가 청년이고 구성원의 50% 이상이 청년으로 구성된 단체(고유번호증, 비영리단체등록증, 법인설립허가증 등이 있는 청년단체)'),
#  Document(metadata={'policy_name': '익산형 근로청년수당', 'main_department': '익산시', 'category_large': '일자리', 'category_medium': '재직자', 'min_age': 18, 'max_age': 39, 'start_date_int': 20250414, 'end_date_int': 20250502, 'application_period_str': '20250414 ~ 20250502'}, page_content='정책명: 익산형 근로청년수당\n정책 설명: 중소,중견기업에 취업한 청년들의 보수 지원과 장기근속 및 지역정착지원\n지원 내용: 월30만원씩 최대3년간 지역화폐로 수당지급\n신청 자격: 공고문 참조'),
#  Document(metadata={'policy_name': '청년 면접 정장 대여사업', 'main_department': '익산시', 'operating_department': '익산시', 'category_large': '일자리', 'category_medium': '취업', 'min_age': 18, 'max_age': 39}, page_content='정책명: 청년 면접 정장 대여사업\n정책 설명: 관내 거주 청년의 구직활동 지원\n지원 내용: 구직 청년에게 면접 정장(정장(상·하의), 셔츠, 블라우스, 넥타이, 구두 등) 무료 대여\n\n신청 자격:'),
#  Document(metadata={'policy_name': '청년창업더하기 지원사업', 'main_department': '장수군', 'category_large': '일자리', 'category_medium': '창업', 'min_age': 18, 'max_age': 49, 'start_date_int': 20250304, 'end_date_int': 20250314, 'application_period_str': '20250304 ~ 20250314'}, page_content='정책명: 청년창업더하기 지원사업\n정책 설명: 관내 청년 창업 지원\n지원 내용:  ○ 사업기간 : 2025. 03. ~ 12.\n ○ 사 업 량 : 3개소(명)\n ○ 사업내용 : 관내에 주소를 둔 18세~49세 개인 또는 법인·단체 등에 \n               시설비, 리모델링, 장비구입, 원재료구입, 홍보비 등 지원\n ○ 사 업 비 : 54백만원\n신청 자격: 예비창업자 또는 창업 3년 이내'),
#  Document(metadata={'policy_name': '특성화 전문반 고등학교 육성지원', 'main_department': '장수군', 'category_large': '일자리,교육', 'category_medium': '취업,미래역량강화', 'min_age': 16, 'max_age': 18}, page_content='정책명: 특성화 전문반 고등학교 육성지원\n정책 설명: 특성화 전문반 고등학교 육성지원(자동차, 제빵 관련)\n지원 내용: ▪ 지원대상 : 전북유니텍고등학교\n▪ 지원기준 : 관내 특성화 고등학교\n▪ 지원내용 : 전국･전북기능대회 대비 자동차 기능 영재반 및 조리제빵반 자격증 취득 캠프 운영\n신청 자격:'),
#  Document(metadata={'policy_name': '지역주민 평생교육(중장비운전, 생활용점, 제과제빵 실습반) 운영 지원', 'main_department': '장수군', 'operating_department': '전북유니텍고등학교', 'category_large': '일자리,교육', 'category_medium': '취업,미래역량강화', 'min_age': 0, 'max_age': 0, 'start_date_int': 20250114, 'end_date_int': 20250131, 'application_period_str': '20250114 ~ 20250131'}, page_content='정책명: 지역주민 평생교육(중장비운전, 생활용점, 제과제빵 실습반) 운영 지원\n정책 설명: 지역주민 평생교육(중장비운전, 생활용점, 제과제빵 실습반) 운영 지원\n지원 내용:  ○ 사업기간 : 2025. 3. ~ 2025. 12.\n ○ 사업대상 : 장수군민\n ○ 사업내용 : 지역주민 대상 중장비, 생활용접 및 제과제빵 실기반 운영\n ○ 사 업 비 : 15,000천원\n신청 자격:'),
#  Document(metadata={'policy_name': '전북대학교 계약학과 운영', 'main_department': '장수군', 'category_large': '일자리,교육', 'category_medium': '취업,미래역량강화', 'min_age': 0, 'max_age': 0, 'start_date_int': 20
 'category_large': '주거', 'category_medium': '전월세 및 주거급여 지원', 'min_age': 0, 'max_age': 0, 'start_date_int': 20250512, 'end_date_int': 20250613, 'application_period_str': '20250512 ~ 20250613'}, page_content='정책명: 신혼부부 등 주택전세 및 연월세 자금 대출이자 지원 \n정책 설명: (전세) 주택전세자금(대출잔액 기준)의 대출이율 1.5%(최대 140만원) 지원\n(연월세)사회 초년생 등 연․월세 대출이자 3.5% 지원(고정금리 4%, 도민 0.5% 부담)  \n\n지원 내용: (전세) 주택전세자금(대출잔액 기준)의 대출이율 1.5%(최대 140만원) 지원\n(연월세)사회 초년생 등 연․월세 대출이자 3.5% 지원(고정금리 4%, 도민 0.5% 부담)  \n\n신청 자격:'),
#  Document(metadata={'policy_name': '국민취업지원제도', 'main_department': '고용노동부', 'operating_department': '고용센터', 'category_large': '일자리', 'category_medium': '취업', 'min_age': 15, 'max_age': 34}, page_content='정책명: 국민취업지원제도\n정책 설명: 청년실업자 등에게 원하는 일자리를 찾을 수 있도록 취업지원서비스와 소득지원을 함께 제공하여 노동시장 진입촉진과 경제적 자립기반 마련\n지원 내용: - 맞춤형 취업지원서비스와 소득지원을 함께 제공\n<취업지원서비스>\n.  취업에 필요한 직업훈련, 일경험, 복지프로그램 등 연계\n.  이력서.면접 컨설팅, 일자리정보제공, 동행면접, 채용박람회 등 구직활동지원프로그램\n<소득지원>\n. 참여수당 15~25만원, 직업훈련 참여시  월 최대 28.4만원(6개월)지원 \n. 지원유형에 따라 구직활동 이행 시 구직촉진수당 월 50만원+추가지급(최대 월 40만원)X6개월\n. 최대 150만원 취업성공수당 지원(중위소득60%이하 또는 특정계층)\n\n신청 자격:'),
#  Document(metadata={'policy_name': '신혼, 맞벌이부부 행복 공동육아나눔터 확충', 'main_department': '울산광역시', 'category_large': '복지문화', 'category_medium': '취약계층 및 금융지원', 'min_age': 0, 'max_age': 0}, page_content='정책명: 신혼, 맞벌이부부 행복 공동육아나눔터 확충\n정책 설명: 맞벌이 등으로 약화된 가족돌봄 기능을 보완하고, 지역사회 돌봄 공동체를 구성\n지원 내용:  \n○ 사업규모 : 11개소 (중구 1, 남구 2, 동구 2, 북구 4, 울주군 2)\n\n○ 주요내용\n- (공간 제공) 자녀 돌봄을 위한 안전한 공간 제공\n- (프로그램 운영) 부모와 자녀가 함께하는 부모참여형 프로그램 운영\n- (공동육아 지원) 품앗이 돌봄공동체 구성·운영, 다양한 활동 수행\n- (놀이활동 지원) 다양한 놀이 프로그램을 개발, 놀이활동 촉진 교구 등 지원\n신청 자격:'),
#  Document(metadata={'policy_name': '국공립어린이집 확충', 'main_department': '울산광역시', 'category_large': '복지문화', 'category_medium': '취약계층 및 금융지원', 'min_age': 0, 'max_age': 0}, page_content='정책명: 국공립어린이집 확충\n정책 설명: 양질의 보육시설을 통해 보육의 공공성을 강화하고 접근성을 확보하여 저출산 대응\n지원 내용: ○ 사업내용 : 신축, 장기임차, 리모델링 등 국공립어린이집 확충\n    - (신축) 신축, 매입, 기존 공공시설 리모델링\n    - (국공립장기임차) 민간·가정어린이집 장기임차(무상) 국공립전환\n    - (리모델링) 공동주택 관리동 어린이집, 사회복지법인 어린이집 리모델링\n    - (기자재비) 개원 예정 국공립어린이집 기자재비 지원\n \n○ 지원내용\n    - (신축) 1,676천원(㎡)\n    - (국공립장기임차) 리모델링비 50백만원~150백만원, 근저당비용 100백만원\n    - (리모델링) 리모델링비 50백만원~150백만원\n    - (기자재비) 10백만원\n신청 자격:'),
 'category_large': '주거', 'category_medium': '전월세 및 주거급여 지원', 'min_age': 19, 'max_age': 39, 'start_date_int': 20250203, 'end_date_int': 20250512, 'application_period_str': '20250203 ~ 20250512'}, page_content='정책명: 청년 이사비 지원\n정책 설명: 잦은 이사와 주택가격 상승으로 경제적 어려움을 겪고 있는 청년 가구에 이사비를 지원하여 주거비 부담 완화 및 주거안정 도모\n지원 내용: - 이삿짐센터, 입주청소비 등 이사 비용 최대 40만원 한도 내 실비 지원 \n1. (이사비) 사다리차 이용비, 이사업체 포장비, 이사업체 운반비, 용달차량 임차비, 이사박스 구입비\n2. (입주청소비) 청소업체 등을 통한 입주청소 비용\n신청 자격:'),
#  Document(metadata={'policy_name': '전세보증금 반환보증 보증료 지원', 'main_department': '주택토지실', 'category_large': '주거', 'category_medium': '전월세 및 주거급여 지원', 'min_age': 0, 'max_age': 0}, page_content='정책명: 전세보증금 반환보증 보증료 지원\n정책 설명: 전세 사기, 역전세 현상의 주 피해자인 청년층 등 취약계층에게 전세보증금반환보증 보증료를 지원하여 보증가입 유도 및 주거안정 도모\n지원 내용: 신청인이 기납부한 전세보증금반환보증 보증료에 대해 전부 또는 일부(최대 40만원) 지원\n신청 자격:'),
#  Document(metadata={'policy_name': '청년월세 한시 특별지원', 'main_department': '주택토지실', 'category_large': '주거', 'category_medium': '전월세 및 주거급여 지원', 'min_age': 19, 'max_age': 34, 'start_date_int': 20240226, 'end_date_int': 20250225, 'application_period_str': '20240226 ~ 20250225'}, page_content='정책명: 청년월세 한시 특별지원\n정책 설명: 청년층 주거비 부담 경감을 위해 청년월세 한시적 지원 (월 20만원 최대 24개월 지원)\n\n지원 내용: 청년층 주거비 부담 경감을 위해 청년월세 한시적 지원\n(지원내용) 월 20만원 최대 24개월 지원\n(소득기준) 청년가구: 중위소득 60%, 원가구: 중위소득 100%\n(재산기준) 청년가구: 1억2천2백만원, 원가구: 407백만원 이하\n\n신청 자격: 재산기준 122백만원 이하'),
#  Document(metadata={'policy_name': '청년·신혼부부 주거비 지원사업', 'main_department': '장수군', 'category_large': '주거', 'category_medium': '전월세 및 주거급여 지원', 'min_age': 19, 'max_age': 39}, page_content='정책명: 청년·신혼부부 주거비 지원사업\n정책 설명: 관내 청년·신혼부부의 주거비를 지원함으로써 청년과 신혼부부의 경제적 부담을 완화 및 정주여건을 개선\n지원 내용: 사업개요\n  ○ 사업명 : 장수군 청년·신혼부부 주거비 일부 지원\n  ○ 사업기간 : 2025. 4. ~ 2025. 12. \n  ○ 소요예산 : 100,000천원 (1,000천원 × 100가구) \n  ○ 지원대상 : 공고일 현재 관내 주소를 두고 실 거주하는 중위소득 150% 이하(사업소득 또는 근로소득자, 구직급여 수급자격자) 청년·신혼부부 무주택 임차가구(주거공급면적 85㎡ 이하)\n     - (청년) 19세~39세 이하 미혼자\n        ※ 2025년 기준 출생연도 : 1986.1.1. ~ 2006.12.31.\n     - (신혼부부) 혼인신고 후 5년 이내 부부(부부 모두 49세 이하) \n        ※ 2025년 기준 출생연도 : 1976.1.1. ~ 2006.12.31.\n  ○ 지원내용 : 가구당 100만원 이내(연 1회, 최대 3년)\n     - (전세) 대출 잔액의 2% 이내 이자\n     - (월세) 연간 임차료의 30% \\\n  ※ 신청절차, 신청서류 등 기타 사항 공고문 참고\n신청 자격:'),
#  Document(metadata={'policy_name': '정보소외지역SW교육지원강화(SW미래채움)', 'main_department': '대구광역시', 'operating_department': '재단법인대구디지털혁신진흥원', 'category_large': '교육', 'category_medium': '미래역량강화', 'min_age':
 'main_department': '울산광역시', 'category_large': '복지문화', 'category_medium': '취약계층 및 금융지원', 'min_age': 0, 'max_age': 0}, page_content="정책명: 청소년한부모 자립 지원사업\n정책 설명: 청소년 한부모는 어른 한부모가 겪는 빈곤과 자녀양육·생꼐 외 학업중단·취업훈련 부족 등 부가적인 어려움으로 자립기반 마련 지원 필요\n지원 내용: ○ 사업기간 : '25. 1. ~ 12.\n\n○ 지원대상 : 기준 중위소득 65% 이하, 만 18세 미만 자녀 양육 한부모\n                   (모 또는 부의 연령이 만 24세 이하)\n\n○ 지원인원 : 41명(아동양육비 37, 자립촉진 2, 검정고시 지원 2)\n\n○ 지원방법 : 구·군 사업비로 보조금 교부\n\n○ 지원내용 : 자녀 아동양육비(1인 월 37만원), 자립촉진수당(월 10만원), 검정고시학습비(연 154만원이내)\n※ 영아(0~1세) 양육 시 월 40\n\n○ 주관기관 : 5개 구·군\n신청 자격:"),
#  Document(metadata={'policy_name': '청소년쉼터 퇴소청소년 자립지원수당', 'main_department': '울산광역시', 'category_large': '복지문화', 'category_medium': '취약계층 및 금융지원', 'min_age': 0, 'max_age': 0}, page_content="정책명: 청소년쉼터 퇴소청소년 자립지원수당\n정책 설명: 원가정의 보호·지원을 받을 수 없는 쉼터 퇴소 청소년에게 자립지원수당을 지원하여 퇴소 후 사회 안착 지원\n지원 내용:  \n○ 사업기간 : '25. 1. ~ 12. 연중\n\n○ 지원대상 : 청소년쉼터 퇴소일(또는 청소년자립지원관 사례종료일)로 부터\n                   5년 이내인 자로서 다음 모두에 해당하는 경우\n- 만 18세 이후 퇴소한(사례종료된) 자\n※ '21. 1월 이후 쉼터 퇴소자, '24. 1월 이후 자립지원관 사례종료자에 한함\n- 퇴소일(사례종료일) 기준, 쉼터 입소기간 또는 청소년자립지원관 사례관리기간을 합산하여 3년 동안 2년 이상 보호받은 자\n(단, 직전 6개월은 연속하여 보호받았을 것)\n※ 자립지원관 단일 이용만으로 신청불가(쉼터 보호 기간 필요), 쉼터는 입·퇴소 기간만 인정\n※ 보호종료아동 자립수당 수령 이력이 있는 자는 중복지원 불가\n\n○ 지원수준 : 1인당 월 40만원, 퇴소·사례종료 후 5년 이내(최장 60개월)\n\n○ 지원절차 : 신청 → 접수 → 지원결정 →통보·지급 → 사후관리\n신청 자격:"),
#  Document(metadata={'policy_name': '2025년 군산시 청년창업플랫폼(청춘미가) 지원사업', 'main_department': '군산시', 'category_large': '일자리', 'category_medium': '창업', 'min_age': 19, 'max_age': 39, 'start_date_int': 20250716, 'end_date_int': 20250808, 'application_period_str': '20250716 ~ 20250808'}, page_content='정책명: 2025년 군산시 청년창업플랫폼(청춘미가) 지원사업\n정책 설명: 외식창업을 희망하는 예비 청년창업자들의 창업 지원\n지원 내용: ￭ 위    치 : 전북특별자치도 군산시 구영6길 74-1(중앙로1가)\n￭ 면    적 : 대지면적 129㎡, 건축면적 65.08㎡(지상1층)\n￭ 지원내용 : 외식창업을 희망하는 예비 청년 창업자에게 일정기간 동안 사업장 및  기물 무상 대여 \n   ※ 식재료비, 수도요금, 광열비 등 공과금 사업자 부담 \n￭ 입주예정일 : 2025년 8월(2회에 한해서 최대 6개월 연장 가능)\n￭ 운영 전 맛의 표준화, 판매·홍보 전략 등 컨설팅 진행\n신청 자격: 우대조건은 별도 확인'),
#  Document(metadata={'policy_name': '가족돌봄청년 지원사업', 'main_department': '울산광역시', 'category_large': '복지문화', 'category_medium': '취약계층 및 금융지원', 'min_age': 0, 'max_age': 0}, page_content='정책명:
#  Document(metadata={'policy_name': '충남형 농촌리브투게더 ', 'main_department': '건축도시국', 'category_large': '주거', 'category_medium': '주택 및 거주지', 'min_age': 0, 'max_age': 0}, page_content='정책명: 충남형 농촌리브투게더 \n정책 설명: 지속가능한 농촌 주거여건 개선 및 살기좋은 농촌 주거단지 조성을 통해 귀농청년 등 인구 유입으로 농촌인구 감소 방지 및 지방소멸대응\n지원 내용: 기존 농촌 마을주민 주거환경 개선, 귀농청년 등 농촌 유입·정착을 위한 농촌 주거단지 조성, 단독주택으로 조성되며 농촌생활 환경에 적합한 개별창고 제공, 탄소배출 최소화를 위한 목조주택 건립\n신청 자격: 노후주택 거주민 및 귀농청년 등(입주자격 세부조건 시·군 ↔ 도 협의 결정)'),
#  Document(metadata={'policy_name': '충남형 도시리브투게더', 'main_department': '건축도시국', 'operating_department': '충청남도개발공사', 'category_large': '주거', 'category_medium': '주택 및 거주지', 'min_age': 0, 'max_age': 0}, page_content='정책명: 충남형 도시리브투게더\n정책 설명: 청년과 신혼부부 등 무주택 서민에게 “내집 마련 꿈” 기회 제공\n지원 내용: 입주자 모집공고 시 6년 후 분양가격 명시, 결혼 및 출산 등 생애주기 등 고려, 3~4인 가구가 선호하는 전용면적 84㎡ 공급, 대형건설사 책임시공 및 입주자 만족도를 위해 건설사브랜드 그대로 사용, 발코니 확장/시스템 에어컨/붙박이장/중문 무료 제공\n신청 자격:'),
#  Document(metadata={'policy_name': '공공기관 청년고용의무제 운영', 'main_department': '기획조정실', 'operating_department': '충청남도개발공사', 'category_large': '일자리', 'category_medium': '취업', 'min_age': 19, 'max_age': 34, 'start_date_int': 20250901, 'end_date_int': 20251031, 'application_period_str': '20250901 ~ 20251031'}, page_content='정책명: 공공기관 청년고용의무제 운영\n정책 설명: 지방공기업 청년고용의무제를 실시, 사장경영성과계약 이행실적 평가 시 평가하여 고용의무제 100% 달성 노력\n지원 내용: 지방공기업 정원의 100분의3 이상씩 청년 미취업자 고용\n신청 자격: 만 19~34세 이하 취업준비생,\n채용 공고 시 별도로 정하는 요건 만족(거주지등)'),
#  Document(metadata={'policy_name': '지방공기업 체험형 청년인턴 제도 운영', 'main_department': '기획조정실', 'operating_department': '충청남도개발공사', 'category_large': '일자리', 'category_medium': '취업', 'min_age': 19, 'max_age': 34, 'start_date_int': 20250513, 'end_date_int': 20250525, 'application_period_str': '20250513 ~ 20250525'}, page_content='정책명: 지방공기업 체험형 청년인턴 제도 운영\n정책 설명: 청년 대상 일자리 경험 제공 및 취업역량 강화\n지원 내용: 체혐형 청년인턴 제도 운영\n(고용기간 4개월)\n신청 자격: 청년(19~34세) 취업준비생,\n채용 공고 시 별도로 정하는 요건 만족(거주지 등)'),
#  Document(metadata={'policy_name': '자립준비청년 자립 지원 (자립수당, 자립정착금, 대학생활안정자금)', 'main_department': '인구전략국', 'category_large': '복지문화', 'category_medium': '취약계층 및 금융지원', 'min_age': 18, 'max_age': 23}, page_content='정책명: 자립준비청년 자립 지원 (자립수당, 자립정착금, 대학생활안정자금)\n정책 설명: 자립준비청년(보호종료아동)의 안정적인 사회 정착 도모\n지원 내용: - 자립수당 : 자립준비청년에게 자립수당(1인 월 50만원, 최대 60개월) 지원\n- 자립정착금 : 자립준비청년에게 주거 마련 등 자립정착금(1인 1,000만원) 일시 지원\n- 대학생활안정자금 : 대학에 진학한 자립준비청년 및 보호 연장 아동에게 대학생활안정자금(1인 200만원) 일시 지원\n신청 자격: 자립수당 : 보호종료 5년 이내 자립준비청년 중 과거 2년 이상 연속하여 보호 받은 자\n자립정착금, 대학생활안정자금 : 보호종료 5년 이내 자립준비청년\n------------------------------------\n자립수당, 자립정착금 : 학력 제한없음\n대학생활안정자금 : 대학진학자'),
#  Document(metadata={'policy_name': '자립지원 사업', 'main_department': '인구전략국', 'category_large': '복지문화', 'category_medium': '취약계층 및 금융지원', 'min_age':
 'category_large': '교육', 'category_medium': '미래역량강화', 'min_age': 10, 'max_age': 18}, page_content='정책명: 예비청년 현장중심 진로체험 프로그램 운영\n정책 설명: 예비청년의 자기주도적 진로탐색 역량 함양\n지역사회 내 진로체험 자원을 발굴･활용한 지역인재 양성\n지원 내용: - 지역사회 내 다양한 진로체험처 발굴, 관리 지원\n- 예비청년 대상 진로직업체험 프로그램 운영 지원\n신청 자격: 도내 학교에 재학 중인 예비청년'),
#  Document(metadata={'policy_name': '충남학사관 운영', 'main_department': '기획조정실', 'operating_department': '재단법인충청남도평생교육인재육성진흥원', 'category_large': '주거', 'category_medium': '기숙사', 'min_age': 0, 'max_age': 0}, page_content='정책명: 충남학사관 운영\n정책 설명: 충남출신 수도권 및 대전권 소재 대학생들의 정주여건 개선을 위한 학사관 운영\n지원 내용: 충청남도서울학사관, 충청남도대전학사관 운영\n신청 자격: 충남 출신 수도권 및 대전·세종·충남권 소재 대학생, 공동시설 거주에 제한이 없어야 함'),
#  Document(metadata={'policy_name': '청년농업인 농지임차료 지원', 'main_department': '농축산국', 'category_large': '일자리', 'category_medium': '창업', 'min_age': 18, 'max_age': 45, 'start_date_int': 20250701, 'end_date_int': 20250831, 'application_period_str': '20250701 ~ 20250831'}, page_content='정책명: 청년농업인 농지임차료 지원\n정책 설명: 영농기반이 부족한 청년농업인의 경영부담 완화 및 경작권 확보 지원을 통한 안정적 영농정착 지원\n지원 내용: 연간 농지 임차료 최대 70%, 300만원 한도 지원(최대 3년간)\n신청 자격: 전년도 농외소득 3,700만원 이하, 도내 임대차 계약 (농지은행·국공유지·사인간)을 체결한 청년농'),
#  Document(metadata={'policy_name': '청년 도내 농창업 지원', 'main_department': '농축산국', 'category_large': '일자리', 'category_medium': '창업', 'min_age': 18, 'max_age': 45, 'start_date_int': 20250201, 'end_date_int': 20250228, 'application_period_str': '20250201 ~ 20250228'}, page_content='정책명: 청년 도내 농창업 지원\n정책 설명: 농업계학교 졸업(예정) 청년농업인들의 전문지식을 활용한 농창업 지원 및 농업 전문인력 육성\n지원 내용: 농자재, 소모품 구입 등 경상비 지원(1,000만원)\n신청 자격: 농업계 전문교육기관 고교·대학(대학원 포함) 졸업(예정) 후 10년 이내 전공 분야 농창업(예정) 청년농업인\n※ 한국농수산대, 농업마이스터대학, 스마트팜 혁신밸리, 농업계 고교·대학 등'),
#  Document(metadata={'policy_name': '일상돌봄서비스사업', 'main_department': '인구전략국', 'category_large': '복지문화', 'category_medium': '취약계층 및 금융지원', 'min_age': 0, 'max_age': 0, 'start_date_int': 20250101, 'end_date_int': 20251231, 'application_period_str': '20250101 ~ 20251231'}, page_content='정책명: 일상돌봄서비스사업\n정책 설명: 돌봄이 필요한 청․중장년 및 가족돌봄청년에게 돌봄·가사등 서비스 지원하여 일상부담 해소\n지원 내용: - 기본서비스 : 재가돌봄, 가사지원(월 12~72시간)\n- 특화서비스 : 병원동행, 심리지원 등(최대 2개 서비스 신청)\n신청 자격: 돌봄이 필요한 청․중장년(만19~64세)\n가족돌봄청년(만9~39세)'),
#  Document(metadata={'policy_name': '청년내일저축계좌 지원', 'main_department': '인구전략국', 'category_large': '복지문화', 'category_medium': '취약계층 및 금융지원', 'min_age': 19, 'max_age': 39, 'start_date_int': 20250502, 'end_date_int': 20250521, 'application_period_str': '20250502 ~ 20250521'}, page_content='정책명: 청년내일저축계좌 지원\n정책 설명: 저소득청년 근로자가 사회에 안착할 수 있도록 자산형성지원 및 자립 촉진\n지원 내용: - (차상위 이하) 3년간 근로, 매월 10만원 이상 저축하면 매월 30만원 지원\n- (차상위 초과) 3년간 근로, 매월 10만원 이상 저축하면 매월 10만원 지원)\n신청 자격: 차상위 이하 : 기준 중위소득 50%이하, 15세~39세 이하, 월 10만원 이상 근로·사업소득 발생\n차상위 초과 : 기준 중위소득 50%초과 ~ 100%이하, 19~34세 이하, 월 50만원 초과~월 230만원 이하'),
#  Document(metadata={'policy_name': '청년농업인 영농정착지원', 'main_department': '농림축산식품부', 'operating_department': '제주시', 'category_large': '일자리', 'category_medium': '창업', 'min_age': 18, 'max_age': 39, 'start_date_int': 20241218, 'end_date_int': 20250205, 'application_period_str': '20241218 ~ 20250205'}, page_content='정책명: 청년농업인 영농정착지원\n정책 설명: 독립경영 3년이하인 만18세 이상 40세 미만 청년농업인에게 영농정착지원금을 바우처 형태로 지급 \n지원 내용:    - 영농정착 지원금 지급: 영농경력에 따라 차등 지급\n   - 독립경영 1년차 월 110만원, 2년차 월 100만원, 3년차 월 90만원 지급\n   - 후계농업경영인 육성자금 지원: 세대당 최대 5억원 대출 지원\n신청 자격:'),
#  Document(metadata={'policy_name': '비정규학교 및 학력보완 교육 지원', 'main_department': '제주시', 'operating_department': '자치행정국', 'category_large': '복지문화', 'category_medium': '취약계층 및 금융지원', 'min_age': 0, 'max_age': 0}, page_content='정책명: 비정규학교 및 학력보완 교육 지원\n정책 설명: 비정규학교(동려청소년학교) 운영을 통해 정규교육과정(초등, 중등, 고등학교)을 이수하지 못한 학교 밖 청소년 또는 청년 대상 학력 보완 교육을 지원함\n지원 내용: 비정규학교(동려청소년학교) 운영을 통해 정규교육과정(초등&middot;중등&middot;고등)을 이수하지 못한 학교 밖 청소년 또는 청년 대상 학력 보완 교육을 지원함\n\n○ 동려청소년학교\n - 위치: 광양4길 30-1\n - 지원대상: 정규교육과정을 이수하지 못한 학교 밖 청소년 또는 청년\n - 운영내용\n   &middot; 검정고시 대비 교과목 교육 운영\n   &middot; 진로탐색 프로그램 운영\n   &middot; 현장체험학습 운영\n신청 자격:'),
#  Document(metadata={'policy_name': '청년농업인 육성 종합체계 구축', 'main_department': '당진시', 'operating_department': '당진시', 'category_large': '교육', 'category_medium': '미래역량강화', 'min_age': 18, 'max_age': 39}, page_content='정책명: 청년농업인 육성 종합체계 구축\n정책 설명: 청년농업인 작목별 네트워크 형성 및 역량 강화 \n지원 내용: 관내 청년 농업인 및 청년농 유입가능 학생 등을 대상으로 청년농업인 소통 및 화합 행사 및 청년농업인 품목별 모임체 구성 및 활동 지원(대면, 집합 교육)\n신청 자격:'),
#  Document(metadata={'policy_name': '청년창업농 디딤돌 사업', 'main_department': '당진시', 'operating_department': '당진시', 'category_large': '복지문화', 'category_medium': '취약계층 및 금융지원', 'min_age': 18, 'max_age': 39}, page_content='정책명: 청년창업농 디딤돌 사업\n정책 설명: 청년농업인 영농 초기 자립을 위한 영농정착 지원\n지원 내용: 관내 청년농업인(독립경영 5년 이하)을 대상으로 창농기반 구축을 위한 시설 및 장비 지원(보조금 지급)\n신청 자격:'),
#  Document(metadata={'policy_name': '청년농업인 후원결연 멘토링 지범 시범 사업', 'main_department': '당진시', 'operating_department': '당진시', 'category_large': '교육', 'category_medium': '미래역량강화', 'min_age': 18, 'max_age': 39}, page_content='정책명: 청년농업인 후원결연 멘토링 지범 시범 사업\n정책 설명: 청년농업인간 선도기술 협력체계 구축\n지원 내용: 관내 청년농업인 대상, 영농기술 배양을 위한 현장실습 교육비를 지급하여 멘토-멘티 현장실습 교육 실시\n신청 자격:'),
#  Document(metadata={'policy_name': '창의융합형 인재육성 사업', 'main_department': '당진시', 'operating_department': '당진시', 'category_large': '교육', 'category_medium': '미래역량강화', 'min_age': 18, 'max_age': 39}, page_content='정책명: 창의융합형 인재육성 사업\n정책 설명: 4차 산업혁명에 대응하는 창의융합형 인재 양성 및 메이커스 문화 확산을 위한 당진 청년타운 스튜디오 및 메이커스페이스 운영\n지원 내용: ㅇ 미디어 인재 양성 프로그램\nㅇ 콘텐츠 인재 양성 프로그램\nㅇ 메이커 인재 양성 프로그램\nㅇ 장비활용 역량강화 프로그램\nㅇ 지역 수요 맞춤형 프로그램\n신청 자격:'),
#  Document(metadata={'policy_name': '서천군 청년 다드림 지원사업', 'main_department': '서천군', 'operating_department': '서천군', 'category_large': '복지문화', 'category_medium': '취약계층 및 금융지원', 'min_age': 18, 'max_age': 45, 'start_date_int': 20250102, 'end_date_int': 20251231, 'application_period_str': '20250102 ~ 20251231'}, page_content='정책명: 서천군 청년 다드림 지원사업\n정책 설명: 기존 시행중인 인구정책 및 청년정책과 연계하여 청년들의 생애주기별 맞춤형 청년정책 지원 강화를 통한 수요자 중심의 복합서비스 제공\n지원 내용: 단계별 지원(성장➜도약➜정착)으로 개인 역량 강화 및 안정적인 정착 지원\n□ 오프라인 개인학습 및 온라인 수강료 비용 지원\n  ○ 지원목적 : 다양한 교육활동 기회 제공을 통한 개인역량 강화\n  ○ 지원대상 : 서천군에 거주하는 18세~45세 청년 75명(선착순)\n  ○ 지원금액 : 1인당 최대 200,000원 ※ 2025. 1. 1. 이후 결제한 비용에 한하여 지원\n  ○ 지원내용(생애주기별 1회)\n    - 서천군 관내 스터디카페, 독서실 학습비용\n    - 국가기술자격증, 국가전문자격증, 어학시험, 한국사 등 온라인 강의 수강료 지원\n\n□ (예비)신혼부부 결혼비용(스드메) 지원\n  ○ 지원목적 : 결혼 비용 지원을 통한 경제적 부담 완화\n  ○ 지원대상 : (배우자 포함)서천군에 거주 중이면서 결혼한(공고일 이후) 18세~45세 부부 또는 예정인 예비 신혼부부 20쌍(선착순)\n  ○ 지원금액 : 1인당 최대 500,000원 ※ 2025. 1. 1. 이후 결제한 비용에 한하여 지원\n  ○ 지원내용 : 스튜디오, 메이크업, 드레스 등 결혼 비용 지원(생애주기별 1회)\n\n□ 신혼부부 HPV 예방접종 비용\n  ○ 지원목적 : 행복하고 건강한 결혼 생활 지원\n  ○ 지원대상 : (배우자 포함)서천군에 거주 중이면서 결혼한(공고일 이후) 18세~45세 부부 또는 예정인 예비 신혼부부 20명(선착순)\n  ○ 지원금액 : 1인당 최대 300,000원 ※ 2025. 1. 1. 이후 결제한 비용에 한하여 지원\n  ○ 지원내용 : HPV 예방접종 비용 지원(생애주기별 1회)\n\n□ 청년 가족 체험활동비 지원\n  ○ 지원목적 : 가족과 함께하는 활동 및 체험 기회 제공을 통한 행복하고 살기 좋은 육아 여건 조성\n  ○ 지원대상 : (가족 구성원 모두)서천군에 거주 중이면서 0~13세 자녀를 둔 18세~45세 부부(배우자 모두)으로 구성된 가족 40팀(선착순)\n  ○ 지원금액 : 1가구당 최대 100,000원 ※ 2025. 1. 1. 이후 결제한 비용에 한하여 지원\n  ○ 지원내용 : 0~13세 자녀의 가족 체험 프로그램 활동비용 지원(생애주기별 1회)\n    - 목공, 원예, 고구마 캐기, 그림, 전통체험 등 체험·활동 프로그램\n    - 박물관, 미술관, 국립생태원 등 입장료(각 체험별 체험활동보고서 작성)\n    ※ 단순 식사, 숙박비(캠핑포함), 교통비, 다과비 등 지원 불가\n\n□ 지원방식 : 모바일 서천사랑상품권\n신청 자격:'),
#  Document(metadata={'policy_name': '청년 공공근로사업', 'main_department': '서천군', 'operating_department': '서천군', 'category_large': '일자리', 'category_medium': '취업', 'min_age': 18, 'max_age': 45, 'start_date_int': 20250102, 'end_date_int': 20251231, 'application_period_str': '20250102 ~ 20251231'}, page_content='정책명: 청년 공공근로사업\n정책 설명: 취업&middot;취약계층의 생활안정과 실업난 해소를 위해 한시적 직접일자리를 제공하여 고용안정 및 지역경제 활성화 도모\n지원 내용: 공공기관 행정 사무보조 기간제근로자 채용 지원\n신청 자격:'),
#  Document(metadata={'policy_name': '서천군 청년 취업 지원사업', 'main_department': '서천군', 'operating_department': '서천군', 'category_large': '일자리', 'category_medium': '취업', 'min_age': 18, 'max_age': 45, 'start_date_int': 20250113, 'end_date_int': 20251220, 'application_period_str': '20250113 ~ 20251220'}, page_content='정책명: 서천군 청년 취업 지원사업\n정책 설명: 서천군에 거주하는 청년에게 면접수당-취업성공수당-근속수당을 단계적으로 지원하여 청년의 구직활동과 장기근속 장려 및 지역 정착 도모\n지원 내용: □ 면접수당, 취업성공수당, 근속수당 지원 (1인 최대 200만원)\n※ 2020년도부터 누적하여 최대 1인당 200만원을 초과할 수 없음\n\n□ 면접수당\n  ○ 지원목적 : 취업난으로 어려움을 겪는 청년의 구직활동 장려\n  ○ 지원대상 : 서천군에 거주하는 만 18세~45세 미취업 청년\n  ○ 지원내용 : 면접 1회 50천원, 최대 6회 300천원\n  ○ 지원요건\n    - 면접 응시일 기준 서천군에 주민등록된 미취업자\n    - (2024. 8. 1. 이후) 서천군 소재 사업장 면접 응시자\n    - 지역순환경제센터, 워크넷, 지역신문 등 공식적인 채용공고를 통한 면접\n\n□ 취업성공수당\n  ○ 지원목적 : 청년의 근로의욕 고취로 경제활동 참여 유도\n  ○ 지원대상 : 서천군에 거주하는 만 18세~45세 취업성공 청년\n  ○ 지원내용 : 500천원(1인당 1회 한정)\n  ○ 지원요건\n    - 신청일일 기준 서천군에 주민등록된 자\n    ※ 타 시군에서 서천군으로 전입한 경우 전입일로부터 4개월 기간산정하여 지원\n    - (2024. 8. 1. 이후) 서천군 소재 사업장에 채용되어 4개월 경과된 자\n    - 근로계약 체결 및 4대보험 가입\n    - 동일 사업장에서 비정규직에서 정규직으로 채용되더라도 취업성공수당의 취업일은 동일 사업장의 비정규직 채용 시점으로 본다.(건강보험 자격득실확인서의 자격취득일을 취업일로 본다)\n\n□ 근속수당\n  ○ 지원목적 : 임금보전 및 장기재직 유도로 청년의 지역정착 도모\n  ○ 지원대상 : 서천군에 거주하는 만 18세~45세 재직청년\n  ○ 지원내용 : 월 10만원, 최대 12개월\n  ○ 지급기간 : 6개월 이상 재직 후 취업일로부터 소급하여 기간산정\n  ○ 지원요건\n    - (2024. 1. 1. 이후) 서천군 소재 사업장에 채용되어 재직중인 자\n    - 최소 재직기간이 6개월 이상 되는 자\n    - 재직기간에 서천군에 주민등록된 자*\n      * 재직 중에 타 시군에서 서천군으로 전입한 경우 전입일로부터 기간 산정하여 지원\n    - 근로계약 체결 및 4대보험 가입\n\n신청 자격: (면접수당)면접 응시일 기준 서천군에 주민등록된 미취업자\n(취업성공수당)서천군 소재 사업장에 채용되어 4개월 경과된 자\n(근속수당)서천군 소재 사업장에 채용되어 6개월 경과된 자'),
#  Document(metadata={'policy_name': '서천군 청년 행복주거비 지원', 'main_department': '서천군', 'operating_department': '서천군', 'category_large': '주거', 'category_medium': '전월세 및 주거급여 지원', 'min_age': 19, 'max_age': 45, 'start_date_int': 20250414, 'end_date_int': 20250418, 'application_period_str': '20250414 ~ 20250418'}, page_content='정책명: 서천군 청년 행복주거비 지원\n정책 설명: 청년들의 주거비 부담을 해소하고 장기적으로 안정된 생활을 지원하여 청년 인구 유출 방지 및 지역 정착 도모\n지원 내용: 서천군에 주소를 둔 18세~45세 무주택 세대주 청년에게 전·월세, 주택 구입 등에 따른 주거비를 월15만원에서 가구원수에 따라 최대 29만원까지 2년간 지원\n신청 자격: □ 거주지 : 서천군에 계속해서 주소를 두고 있는 자\n※ 외국인은 신청 불가[단, 가족관계등록부에 등재되고 외국인 등록(또는 국내거소신고)을 한 경우에는 신청 가능]\n□ 연령 : 19세 ~ 45세 청년 (생년월일이 1979.1.1.~2006.12.31.)\n□ 주거\n(월세)윌세 60만원 이하(단, 임차보증금 5천만원 이하)\n(전세)전세금 1억원 이하\n(매매)무주택자 대출 승인자(대출승인일 2021. 1. 1.이후인 자) 등'),
#  Document(metadata={'policy_name': '2025년 청년 희망이음 일자리 지원사업', 'main_department': '서귀포시', 'operating_department': '서귀포시', 'category_large': '일자리', 'category_medium': '취업', 'min_age': 19, 'max_age': 39, 'start_date_int': 20241231, 'end_date_int': 20250107, 'application_period_str': '20241231 ~ 20250107'}, page_content='정책명: 2025년 청년 희망이음 일자리 지원사업\n정책 설명: 서귀포시 관내 미취업 청년에게 일자리 제공을 통한 사회 진출 자립기반 마련\n지원 내용: 서귀포시 관내 미취업 청년(만19세 ~ 39세)에게 공공일자리를 제공하여 사회적 진출기반 마련 및 공직분야 업무경험을 통한 진로탐색 기회 제공\n신청 자격: 공고일 현재 서귀포시에 주소를 둔 미취업 청년(19세~39세)'),
#  Document(metadata={'policy_name': '전북청년 2025', 'main_department': '전북특별자치도', 'category_large': '복지문화', 'category_medium': '예술인지원', 'min_age': 18, 'max_age': 40, 'start_date_int': 20240923, 'end_date_int': 20241018, 'application_period_str': '20240923 ~ 20241018'}, page_content='정책명: 전북청년 2025\n정책 설명: 청년미술가 창작활동 지\n지원 내용: 전북 청년미술가의 창작활동 지속성 확보 및 안정적인 환경을 제공으로 창작역량강화 및 활동기반 마련\n신청 자격:'),
#  Document(metadata={'policy_name': '순창 청년 커뮤니티 활동 지원', 'main_department': '순창군', 'category_large': '참여권리', 'category_medium': '청년참여', 'min_age': 18, 'max_age': 49, 'start_date_int': 20240816, 'end_date_int': 20240830, 'application_period_str': '20240816 ~ 20240830'}, page_content='정책명: 순창 청년 커뮤니티 활동 지원\n정책 설명: 청년들로 구성된 모임(팀)의 커뮤니티 활성화 및 활동을 위한 비용 지원\n지원 내용: 지역의 청년(18~49세) 4인 이상으로 구성된 모임에 커뮤니티 활동을 위한 비용 지원 (팀당 최대 1백만원)\n신청 자격:'),
#  Document(metadata={'policy_name': '순창 청년 리빙랩 프로젝트', 'main_department': '순창군', 'category_large': '참여권리,참여권리', 'category_medium': '청년참여,정책인프라구축', 'min_age': 18, 'max_age': 49, 'start_date_int': 20240816, 'end_date_int': 20240830, 'application_period_str': '20240816 ~ 20240830'}, page_content='정책명: 순창 청년 리빙랩 프로젝트\n정책 설명: 청년들이 생각하는 지역 문제를 직접 발굴 및 해결하는데 소요되는 비용(활동비)을 지원\n지원 내용: 지역에 거주하는 청년(18~49세) 4인 이상으로 구성된 팀에게 지역 현안 문제를 청년이 직접 발굴․해결하기 위해 소요되는 활동비 지원\n신청 자격:'),
#  Document(metadata={'policy_name': '2024년 근로 자녀장려금 기한 후 신청', 'main_department': '국세청', 'operating_department': '국세청', 'category_large': '복지문화', 'category_medium': '예술인지원', 'start_date_int': 20240601, 'end_date_int': 20241202, 'application_period_str': '20240601 ~ 20241202'}, page_content="정책명: 2024년 근로 자녀장려금 기한 후 신청\n정책 설명: ○ 근로장려금 이란?\n소득과 재산이 일정 금액 미만인 근로자, 종교인 또는 사업자(전문직 제외)가구에 대해 일하는 만큼 가구원 구성과 총급여액 등(부부합산)에 따라 산정된 근로장려금을 지급하여 근로를 장려하고 소득을 지원하는 일과 연계된\n복지제도입니다.\n○ 자녀장려금 이란?\n자녀양육을 지원하기 위해 총소득(부부합산) 7,000만 원 미만이면서 부양자녀(18세 미만)가 있는 경우 1명당 최대 100만 원을 지급하는 제도입니다.\n지원 내용: ○ 근로장려금\n○ 자녀장려금\n※ 자세한 사항은 홈페이지 안내문 내 '지급액 산정' 참고\n신청 자격:"),
#  Document(metadata={'policy_name': '2024년 하반기 서울 강동구 1인가구 안심장비사업  지원대상자 2차모집 공고', 'main_department': '강동구청 가족정책과 1인가구지원팀', 'operating_department': '강동구청 가족정책과 1인가구지원팀', 'category_large': '복지문화', 'category_medium': '예술인지원', 'start_date_int': 20241101, 'end_date_int': 20241129, 'application_period_str': '20241101 ~ 20241129'}, page_content='정책명: 2024년 하반기 서울 강동구 1인가구 안심장비사업  지원대상자 2차모집 공고\n정책 설명: 강동구에서 주거안전이 취약한 1인가구를 대상으로 2024년 하반기 안심장비 지원대상자를 모집\n지원 내용: 지원물품: 스마트초인종, 가정용 CCTV, 현관문 안전장치\n지원방법: 물품 배송 및 설치 지원(선정 후 업체에서 순차적으로 유선 연락)\n신청 자격:'),
#  Document(metadata={'policy_name': '2024년 한국장학재단 금융 취약계층을 위한 특별 채무조정', 'main_department': '한국장학재단 대출상환상담센터', 'operating_department': '한국장학재단 대출상환상담센터', 'category_large': '복지문화', 'category_medium': '예술인지원', 'start_date_int': 20240801, 'end_date_int': 20241129, 'application_period_str': '20240801 ~ 20241129'}, page_content='정책명: 2024년 한국장학재단 금융 취약계층을 위한 특별 채무조정\n정책 설명: 한국장학재단에서 2024년 금융 취약계층을 위한 특별 채무조정을 시행\n지원 내용: 1. 금융 취약계층 지원\n(신청 대상)\n① (청년 채무자) 만 39세 이하* 부실채권 채무자 * 신청 기간 시작일 기준(’24.8.1.)으로 ’84.8.2. 이후 출생자\n② (소상공인 채무자) 「소상공인기본법」 제2조에 따른 소상공인\n※ 신청일로부터 1개월 이내 발급한 소상공인 확인서 제출 필수 (참고)\n(신청 기간) ’24. 8. 1.(목) ~ ’24. 11. 29.(금), 4개월\n※ 상기 일정은 사업 진행 상황에 따라 변동될 수 있음\n(지원 내용) 분할상환약정(채무감면) 체결 요건 완화(공지글 참고)\n\n2. 일반 부실채권 채무자 지원\n(신청 대상) 만 40세 이상* 학자금대출 부실채권 채무자 * 신청 기간 시작일 기준(’24.8.1.)로 ’84.8.1. 이전 출생자\n(신청 기간) ’24. 8. 1.(목) ~ ’24. 11. 29.(금), 4개월\n(선정 방법) 재산·소득 정보에 대한 적격 여부를 심사하여 선정\n(지원 내용) 분할상환약정(채무감면) 체결 요건 완화(공지글 참고)\n\n3. 성실상환자 인센티브 제공\n(신청 대상) 학자금대출(일반, 취업후, 은행보증, 유예대출) 부실채권 채무자 중 분할상환약정을 유지하고, ①, ② 조건을 모두 충족한 자\n- 청년·소상공인 : ① 약정 기간 1년 이상 유지 ② 약정 대상금액의 30% 이상 상환\n- 일반 :  ① 약정 기간 2년 이상 유지 ② 약정 대상금액의 40% 이상 상환\n(신청 기간) ’24. 8. 1.(목) ~ ’24. 11. 29.(금) ※ 상기 일정은 사업 진행 상황에 따라 변동될 수 있음\n(선정 방법) 분할상환 약정기간, 상환율에 대한 적격 여부 심사 후 선정\n(지원 내용) 분할상환약정 유형을 변경하여 연체이자 감면\n- 일반유형 → 일부 감면, 일부감면 유형 → 전액 감면\n* ’20년 이전 대출: 6%(손해금 9%) → 4.5%, ’20년 이후 대출: 대출금리+가산금리(2% → 1%)\n※ 분할상환 약정 93일 이상 연체(약정 파기 기준)한 자는 미납금 모두 상환 시 재약정 체결 가능\n신청 자격:'),
#  Document(metadata={'policy_name': '2024 찾아가는 공직박람회 (서울 11.18.(월), 경기인천 11.21.(목))', 'main_department': '인사혁신처', 'operating_department': '인사혁신처', 'category_large': '일자리', 'category_medium': '재직자', 'start_date_int': 20241111, 'end_date_int': 20241121, 'application_period_str': '20241111 ~ 20241121'}, page_content='정책명: 2024 찾아가는 공직박람회 (서울 11.18.(월), 경기인천 11.21.(목))\n정책 설명: 공직 진출을 희망하거나 진로 설정 단계에 있는 청년층을 직접 찾아가 공직에 대한 가치와 비전을 소통하고 올바른 공직 진출에 대한 실제적인 정보 제공\n지원 내용: ○ 장소\n- 서울권역 : 2024.11.18.(월) 성균관대학교\n- 경기인천 : 2024.11.21.(목), 인천대학교\n\n○ 내용\n- 공직 특강, 멘토링, 모의면접 ※ 지역 출신 공직자 다수\n- 체험 및 이벤트 : 퍼스널 컬러, 네일아트, 공직 네컷 등\n- 경품 추첨 : 무선 이어폰, 백팩, 비타민 등\n신청 자격:'),
#  ...]

# %%
# 청킹(kss)
# 2. kss 청킹

import kss


def split_docs_with_kss(documents: list[Document], chunk_size: int = 500) -> list[Document]:
    """
    kss를 사용해 문서를 문장 단위로 분할하고,
    정해진 chunk_size에 맞게 문장들을 다시 그룹화합니다.
    """
    final_chunks = []
    
    for doc in documents:
        # 1. kss로 전체 page_content를 문장 리스트로 분리
        sentences = kss.split_sentences(doc.page_content)
        
        current_chunk_content = ""
        # 2. 문장들을 순회하며 chunk_size에 가깝게 그룹으로 묶기
        for sentence in sentences:
            # 현재 문장을 추가하면 chunk_size를 초과하는지 확인
            if len(current_chunk_content) + len(sentence) > chunk_size and current_chunk_content:
                # 초과한다면, 현재까지의 내용을 하나의 chunk로 만듦
                final_chunks.append(
                    Document(page_content=current_chunk_content.strip(), metadata=doc.metadata)
                )
                # 새로운 chunk 시작
                current_chunk_content = sentence
            else:
                # 초과하지 않으면, 현재 chunk에 문장 추가
                current_chunk_content += " " + sentence

        # 마지막에 남아있는 chunk를 리스트에 추가
        if current_chunk_content:
            final_chunks.append(
                Document(page_content=current_chunk_content.strip(), metadata=doc.metadata)
            )
            
    return final_chunks

# %%
split_data = split_docs_with_kss(data)
# --- 결과 확인 (실제 실행 시 주석 해제) ---
print(f"원본 Document 수: {len(data)}")
print(f"분할된 Chunk 수 (kss): {len(split_data)}")

if split_data:
    print("\n--- 첫 번째 분할된 Chunk (kss) ---")
    print(split_data[0].page_content)
    print(split_data[0].metadata)
# Out:
# [Kss]: Oh! You have mecab in your environment. Kss will take this as a backend! :D
# 원본 Document 수: 3861
# 분할된 Chunk 수 (kss): 4252
#
# --- 첫 번째 분할된 Chunk (kss) ---
# 정책명: 웹툰캠퍼스 운영 및 인력 양성
# 정책 설명: - 현장 실무형 전문인력 프로그램을 통한 글로벌 웹툰작가 양성
# - 웹툰 창작 및 제작 역량 강화, 산업 활성화 지원
# 지원 내용: - 지역 웹툰작가 양성을 위한 교육 및 프로그램 운영
# - 교육생 월 창작지원금 및 원고료 지원 등
# 신청 자격:
# {'policy_name': '웹툰캠퍼스 운영 및 인력 양성', 'main_department': '문화콘텐츠과', 'operating_department': '재단법인대구디지털혁신진흥원', 'category_large': '복지문화', 'category_medium': '예술인지원', 'min_age': 0, 'max_age': 0, 'start_date_int': 20250501, 'end_date_int': 20250530, 'application_period_str': '20250501 ~ 20250530'}

# %%
# Chroma DB 세팅
# Chroma DB는 FAISS와 달리, 정말 벡터 DB 라이브러리이다.
# 먼저 어떤 임베딩 모델을 사용할지 정하고, 해당 임베딩 모델과 연결된 컬렉션(collection)을 생성해야 한다.

from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings


# # 1. 사용할 임베딩 모델 선택 및 초기화
# # 예시: 로컬에서 실행하는 Ollama 모델 사용
# embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")

# # 2. ChromaDB 컬렉션 생성 (from_documents 메서드 사용)
# # 이 과정에서 LangChain이 documents의 page_content를 임베딩하고, metadata와 함께 저장합니다.
# vectorstore = Chroma.from_documents(
#     documents=split_data,
#     embedding=embedding_model,
#     collection_name="policy_collection", # 컬렉션 이름 지정
#     persist_directory="./chroma_db" # DB를 저장할 경로
# )

# print("ChromaDB에 Document 저장 완료!")

# # 위 과정을 수행하며 이런 오류를 마주쳤다
# BadRequestError: Error code: 400 - {'error': {'message': 'Requested 414416 tokens, max 300000 tokens per request', 'type': 'max_tokens_per_request', 'param': None, 'code': 'max_tokens_per_request'}}
# 이는 임베딩 모델의 API 호출 한도를 초과하여 발생하는 오류로, 비어있는 벡터 DB를 생성 후 반복문을 통해 임베딩하는 것으로 해결해야 한다고 한다.

# %%
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[4], line 7
#       3 import os
#       5 # 임베딩 모델 준비
#       6 # embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")
# ----> 7 embedding_model = OpenAIEmbeddings(model="text-embedding-3-large", openai_api_key=os.getenv("OPENAI_API_KEY"))
#       9 # Chroma DB 준비
#      10 vectorstore = Chroma(
#      11     collection_name="policy_collection_summary_added_openai_large",
#      12     embedding_function=embedding_model,
#      13     persist_directory="./chroma_db_policy"
#      14 )
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/langchain_spike/lib/python3.11/site-packages/langchain_openai/embeddings/base.py:327, in OpenAIEmbeddings.validate_environment(self)
#     325         self.http_client = httpx.Client(proxy=self.openai_proxy)
#     326     sync_specific = {"http_client": self.http_client}
# --> 327     self.client = openai.OpenAI(**client_params, **sync_specific).embeddings  # type: ignore[arg-type]
#     328 if not self.async_client:
#     329     if self.openai_proxy and not self.http_async_client:
#
# File ~/anaconda3/envs/langchain_spike/lib/python3.11/site-packages/openai/_client.py:130, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     128     api_key = os.environ.get("OPENAI_API_KEY")
#     129 if api_key is None:
# --> 130     raise OpenAIError(
#     131         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     132     )
#     133 self.api_key = api_key
#     135 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
# 데이터 처리
def add_to_chroma_in_batches(docs: list[Document], batch_size: int = 100):
    """문서 리스트를 배치로 나누어 ChromaDB에 추가합니다."""
    
    # 전체 문서 리스트를 batch_size만큼 건너뛰며 반복
    for i in range(0, len(docs), batch_size):
        # 현재 처리할 배치 슬라이싱
        batch = docs[i:i + batch_size]
        
        # 현재 배치만 DB에 추가
        vectorstore.add_documents(documents=batch)
        
        # 진행 상황 출력
        print(f"Batch {i//batch_size + 1}/{(len(docs) - 1)//batch_size + 1} 처리 완료 ({len(batch)}개 문서 추가)")

# 함수 호출로 배치 처리 실행
add_to_chroma_in_batches(data, batch_size=200) # 배치 사이즈는 조절 가능

print("\n모든 문서의 배치 처리가 완료되었습니다.")
# Out:
# Batch 1/20 처리 완료 (200개 문서 추가)
# Batch 2/20 처리 완료 (200개 문서 추가)
# Batch 3/20 처리 완료 (200개 문서 추가)
# Batch 4/20 처리 완료 (200개 문서 추가)
# Batch 5/20 처리 완료 (200개 문서 추가)
# Batch 6/20 처리 완료 (200개 문서 추가)
# Batch 7/20 처리 완료 (200개 문서 추가)
# Batch 8/20 처리 완료 (200개 문서 추가)
# Batch 9/20 처리 완료 (200개 문서 추가)
# Batch 10/20 처리 완료 (200개 문서 추가)
# Batch 11/20 처리 완료 (200개 문서 추가)
# Batch 12/20 처리 완료 (200개 문서 추가)
# Batch 13/20 처리 완료 (200개 문서 추가)
# Batch 14/20 처리 완료 (200개 문서 추가)
# Batch 15/20 처리 완료 (200개 문서 추가)
# Batch 16/20 처리 완료 (200개 문서 추가)
# Batch 17/20 처리 완료 (200개 문서 추가)
# Batch 18/20 처리 완료 (200개 문서 추가)
# Batch 19/20 처리 완료 (200개 문서 추가)
# Batch 20/20 처리 완료 (61개 문서 추가)
#
# 모든 문서의 배치 처리가 완료되었습니다.

# %%
# 데이터가 잘 저장되었는지 확인
# vectorstore.persist()
# .persist()가 이전 버전에서 필요했던 이유는 쓰기 작업이 강제로 플러시될 때만 수행되었기 때문입니다. Chroma 0.4.0은 모든 쓰기를 즉시 디스크에 저장하므로 persist가 더 이상 필요하지 않습니다.

retriever = vectorstore.as_retriever()
results = retriever.invoke("예술 관련 정책 찾아줘")
print(results)
# Out:
# [Document(id='8c3707f0-a7bd-4f66-ae79-2438879ba780', metadata={'category_large': '참여권리,참여권리', 'policy_name': '<군산회관 돌아보기〉투어 참여자 모집 (무료)', 'main_department': '소통협력센터 군산', 'category_medium': '청년참여,정책인프라구축', 'start_date_int': 20241021, 'application_period_str': '20241021 ~ 20241110', 'end_date_int': 20241110, 'operating_department': '소통협력센터 군산'}, page_content='정책명: <군산회관 돌아보기〉투어 참여자 모집 (무료)\n정책 설명: -\n지원 내용: -\n신청 자격: -'), Document(id='29058c11-21cf-4599-aea3-0a3b676735e4', metadata={'category_medium': '취업', 'max_age': 34, 'end_date_int': 20240923, 'policy_name': '2024 미래내일 일경험 참여청년 모집 (문화예술)', 'start_date_int': 20240920, 'main_department': '베스트인', 'category_large': '일자리', 'application_period_str': '20240920 ~ 20240923', 'min_age': 15, 'operating_department': '베스트인'}, page_content='정책명: 2024 미래내일 일경험 참여청년 모집 (문화예술)\n정책 설명: -\n지원 내용: 근무조건, 급여 등은 참고사이트 참조\n신청 자격: -'), Document(id='a57eb6a1-9c8f-4dc5-bfed-334a3ca7a3b4', metadata={'category_large': '교육,교육', 'application_period_str': '20241029 ~ 20241101', 'main_department': '전주문화재단', 'end_date_int': 20241101, 'operating_department': '전주문화재단', 'start_date_int': 20241029, 'policy_name': '전주문화재단x예술경영지원센터, 2024 찾아가는 아트코리아랩 비즈센터 개최 안내(11.5)', 'category_medium': '미래역량강화,온라인교육'}, page_content='정책명: 전주문화재단x예술경영지원센터, 2024 찾아가는 아트코리아랩 비즈센터 개최 안내(11.5)\n정책 설명: -\n지원 내용: -\n신청 자격: -'), Document(id='2ec6a7ca-40f3-4de8-8601-b8fc52e3b7a2', metadata={'operating_department': '청년뜰', 'max_age': 39, 'main_department': '군산시', 'category_medium': '건강', 'category_large': '복지문화', 'end_date_int': 20241010, 'policy_name': '집단상담 2차 참여자 모집', 'start_date_int': 20240926, 'min_age': 18, 'application_period_str': '20240926 ~ 20241010'}, page_content='정책명: 집단상담 2차 참여자 모집\n정책 설명: 미술치료프로그램과 더불어 의사소통관계 유형 검사를 통해 스스로를 이해하고 관계 속의 나 자신도 탐구해보는 시간을 가져보세요!\n지원 내용: 운영내용: 미술 치료 프로그램(그림검사, 한지염색)을 통한 내면 탐색 및 의사소통 유형 검사를 통한 자기이해\n신청 자격:')]

# %%
# 조건 쿼리 테스트
# 연도, 나이 범위로 먼저 필터링 해보자!

# %%
# --- 시나리오 1: 특정 카테고리 필터링 ---
# '일자리' 분야의 정책 중에서 '청년 지원'과 관련된 내용 검색
print("--- [시나리오 1] 카테고리 필터링: '일자리' 분야 ---")
results_category = vectorstore.similarity_search(
    query="청년 지원",
    k=5,
    filter={"category_large": "일자리"} # category_large 메타데이터가 '일자리'인 문서만 대상
)
for doc in results_category:
    print(f"  - 정책명: {doc.metadata.get('policy_name', 'N/A')}")
    print(f'내용\n {doc.page_content}')
    print("-" * 20)
# Out:
# --- [시나리오 1] 카테고리 필터링: '일자리' 분야 ---
#   - 정책명: 청년마을활동가 양성 및 지원
# 내용
#  정책명: 청년마을활동가 양성 및 지원
# 정책 설명: 청년 활동가들이 지역 주민의 복지 증진과 지역 공동체 형성촉진 활동에 주체적으로 참여할 수 있도록 지원
# 지원 내용: 마을 활동가 선발 시 청년(30~39세) 대상으로 가점 부여
# 신청 자격:
# --------------------
#   - 정책명: 기장군 청년 면접수당 지원 사업
# 내용
#  정책명: 기장군 청년 면접수당 지원 사업
# 정책 설명: 취업준비 청년에 면접수당을 지원하여 청년의 경제적 부담 완화
# 지원 내용: 19세  ~ 39세 청년에 대해 면접비용 1회 5만원 연 최대 2회까지 지원
# 신청 자격:
# --------------------
#   - 정책명: 청년 작가 전시 지원사업
# 내용
#  정책명: 청년 작가 전시 지원사업
# 정책 설명: 청년센터 마을기록관(전시공간)을 활용하여 청년작가들에게 전시 기회를 제공
# 청년작가들의 발굴·육성
# 지원 내용: 전시공간 및 홍보지원
# 신청 자격:
# --------------------
#   - 정책명: (부평구)청년도전 지원사업
# 내용
#  정책명: (부평구)청년도전 지원사업
# 정책 설명: 구직단념청년을 발굴, 노동시장 참여 촉진지원
# 지원 내용: 맞춤형 프로그램 및 참여수당, 인센티브 등
# 신청 자격:
# --------------------
#   - 정책명: 청년 자격시험 응시료 지원
# 내용
#  정책명: 청년 자격시험 응시료 지원
# 정책 설명: 우리 구에서는 청년들의 능력개발과 구직활동에 필요한 국가기술자격시험 등 자격증 응시료의 지원을 통해 미취(창)업 청년들의 경제적 부담을 완화하고자  「2025년 부산 북구 청년 자격시험 응시료 지원 사업」 을 실시합니다.
# 지원 내용: 취업준비 청년의 경제적 부담 완화, 직무역량 향상, 취업 도전 기회 마련
#
# 대상 : 북구 거주 미취업 청년
# 주요내용 : 어학 등 자격시험 응시료 실비 지원 (1인당 1종 연 1회 10만원 한도)
#                ‣ 1인당 1종 연1회 : 하나의 자격증 시험(1종)에 대해 연1회 실비 지원이 가능
#                ‣ 하나의 자격증 시험이 단계 또는 실기/필기 등으로 나뉘어 있을 시, 실기 및
#                   필기를 1종으로 산정하여 실기와 필기 묶어서 신청 가능
#                  ※ 격년신청 가능‧생애 최대 3회 한정 : 24년 수혜자 25년 지원 불가
#
# 세부사항 붙임 공고문 참고
#
# 신청 자격:
# --------------------

# %%
# --- 시나리오 2: 나이(숫자 범위) 필터링 ---
# 만 19세 이상 39세 미만 청년을 대상으로 하는 정책 검색
print("\n--- [시나리오 2] 숫자 범위 필터링: 19세 이상 39세 미만 ---")
results_age = vectorstore.similarity_search(
    query="자금 지원",
    k=5,
    filter={
        "$and": [
            {"min_age": {"$gte": 19}}, # 'min_age'가 19보다 크거나 같고
            {"max_age": {"$lt": 39}}   # 'max_age'가 39보다 작은 문서
        ]
    }
)
for doc in results_age:
    print(f"  - 정책명: {doc.metadata.get('policy_name', 'N/A')}, 연령: {doc.metadata.get('min_age')}~{doc.metadata.get('max_age')}")
    print(f'내용\n {doc.page_content}')
    print("-" * 20)
# Out:
# --- [시나리오 2] 숫자 범위 필터링: 19세 이상 39세 미만 ---
#   - 정책명: 경상남도 청년주택 임차보증금 이자 지원사업, 연령: 19~34
# 내용
#  정책명: 경상남도 청년주택 임차보증금 이자 지원사업
# 정책 설명: -
# 지원 내용: □ 사업내용 : 청년 주거 안정을 위한 주택임차보증금 융자 추천 및 이자 지원
# - 임차보증금 1억원 이하, 전용면적 60㎡ 이하의 주택 임차보증금 융자 추천(최대 9천만원 한도)
# - 4천만원 한도 주택 임차보증금 대출금의 이자 3% 지원(최장 6년간)
# 신청 자격: -
# --------------------
#   - 정책명: 입영지원금(남양주시), 연령: 19~30
# 내용
#  정책명: 입영지원금(남양주시)
# 정책 설명: 현역병 또는 사회복무요원으로 입영(소집) 예정인 남양주시민에게 병역의무 이행 격려 지원금
# 지원 내용: - 지급내용 : 1인당 10만원 남양주사랑상품권(지역화폐) 지급 (최초 입영 1회에 한함)
# - 신청주체 : 입영자 본인 또는 대리인*
# * 주민등록상 가족 중 성년자, 배우자, 직계존비속, 직계존비속의 배우자, 배우자의 직계존비속
# * 신청 대리인 : 가족관계증명서 제출
# 신청 자격:
# --------------------
#   - 정책명: [이천시] 중소기업 청년노동자 근속장려금 지원사업, 연령: 19~35
# 내용
#  정책명: [이천시] 중소기업 청년노동자 근속장려금 지원사업
# 정책 설명: 이천시 청년노동자를 위한 「중소기업 청년노동자 근속장려금 지원」 사업
# 지원 내용: ○ 지원내용 : 1인당 2년 이상 근속 시 총 300만원 지역화폐 지급
# 신청 자격:
# --------------------
#   - 정책명: 청년근로자 근속장려금 지원, 연령: 19~34
# 내용
#  정책명: 청년근로자 근속장려금 지원
# 정책 설명: 관내 중소기업에서 정규직으로 2년 이상 재직 중인 청년근로자에게 근속장려금을 강릉사랑상품권으로 지급
# 지원 내용: 근속장려금 50만 원 지급
# 신청 자격:
# --------------------
#   - 정책명: 청년 사업자 및 창업자 월 임차료 지원, 연령: 19~34
# 내용
#  정책명: 청년 사업자 및 창업자 월 임차료 지원
# 정책 설명: 청년 사업자의 창업환경 안정화와 생업보호를 위해 연 최대 200만원의 월 임차료 지원
# 지원 내용: □ 사업장 월 임차료 연 최대 200만원 지원
# ○ 20만원 x 10개월(3~12월)  * 3~5월분 소급 지원
# ○ 선정자 본인 계좌로 현금이체
# 신청 자격: -
# --------------------

# %%
# --- 시나리오 3: 숫자형 날짜(YYMMDD) 필터링
today_int = int(datetime.now().strftime("%Y%m%d"))
print(f"오늘 날짜(정수형): {today_int}\n")

# 3. '현재 신청 가능한' 정책 필터링 검색
print("--- 현재 신청 가능한 정책 검색 (정수 비교) ---")
results_ongoing = vectorstore.similarity_search(
    query="주거 지원",
    k=3,
    filter={
        "$and": [
            {"start_date_int": {"$lte": today_int}},
            {"end_date_int": {"$gte": today_int}}
        ]
    }
)

if not results_ongoing:
    print("현재 신청 가능한 정책이 없습니다.")
else:
    for doc in results_ongoing:
        print(f"  - 정책명: {doc.metadata.get('policy_name', 'N/A')}")
        print(f"    신청 기간: {doc.metadata.get('application_period_str', 'N/A')}")
# Out:
# 오늘 날짜(정수형): 20250721
#
# --- 현재 신청 가능한 정책 검색 (정수 비교) ---
#   - 정책명: 주거취약계층 부동산 중개보수 지원
#     신청 기간: 20250101 ~ 20251231
#   - 정책명: 청년 취업 면접정장 지원
#     신청 기간: 20250203 ~ 20251128
#   - 정책명: 청년 신혼부부 주거자금 대출이자 지원사업
#     신청 기간: 20250701 ~ 20250731

# %%
# --- 시나리오 4: 복합 조건 필터링 ($or 사용) ---
# '보건복지부' 또는 '여성가족부'에서 주관하며, '주거' 또는 '금융' 분야인 정책 검색
print("\n--- [시나리오 4] 복합 조건 필터링: 부처 및 분야 동시 검색 ---")
results_complex = vectorstore.similarity_search(
    query="저소득층 지원",
    k=5,
    filter={
        "$and": [
            {
                "$or": [
                    {"main_department": "보건복지부"},
                    {"main_department": "여성가족부"}
                ]
            },
            {
                "$or": [
                    {"category_large": "주거"},
                    {"category_large": "금융"}
                ]
            }
        ]
    }
)
for doc in results_complex:
    print(f"  - 정책명: {doc.metadata.get('policy_name', 'N/A')}, 주관부처: {doc.metadata.get('main_department')}, 분야: {doc.metadata.get('category_large')}")
print("-" * 20)
# Out:
# --- [시나리오 4] 복합 조건 필터링: 부처 및 분야 동시 검색 ---
#   - 정책명: 청소년부모 아동양육비 지원 사업, 주관부처: 여성가족부, 분야: 주거
#   - 정책명: (건강보험) 임의계속가입제도, 주관부처: 보건복지부, 분야: 주거
# --------------------

# %%
# 이제 이렇게 조건 기반 쿼리를 사용할 준비가 되었다면..
# 사용자의 질문을 가공하여 쿼리로 변환해야 한다.
# 대표적으로 규칙기반(정규식 등)과 LLM을 활용한 방법이 있다.

# 규칙기반 시스템의 경우..
# 장점 (Pros)	단점 (Cons)
# ✅ 매우 빠름 (LLM API 호출 없음)	⚠️ 유연하지 않음 ("내년이면 서른" 같은 표현 처리 불가)
# ✅ 예측 가능하고 일관적임	⚠️ 규칙이 복잡해지면 유지보수가 어려움 (if/elif 지옥)
# ✅ 비용이 들지 않음	⚠️ 새로운 패턴에 취약함

# LLM을 활용할 경우..(자연어 이해-NLU)
# 장점 (Pros)	단점 (Cons)
# ✅ 매우 유연하고 강력함 (문맥, 동의어, 복잡한 문장 이해)	⚠️ 느림 (API 네트워크 지연 시간)
# ✅ 유지보수가 쉬움 (프롬프트만 수정하면 됨)	⚠️ 비용 발생 (API 호출 비용)
# ✅ 다양한 사용자 표현에 강함	⚠️ 결과가 100% 일관적이지 않을 수 있음

# 최고의 시스템 및 성능을 원한다면 하이브리드 고려. 
# 하이브리드는 간단하게나마 우리 시스템에도 적용할 수 있을 것 같음.
# 모든 입력에 대해 LLM으로 처리한다면, 많은 비용이 들 것. 
# 즉, 대놓고 이상한 요청은 규칙 기반으로 충분히 처리 가능하므로.. 이를 기반으로 구축.

# %%
# 단계별 필터링 구조(하이브리드)

# 1단계) 사전 차단(Guardrail)
# 대상 : 인사말, 욕설/비속어, 무의미한 입력, 주제와 무관한 질문 등
# 처리 : 미리 준비된 답변을 반환. (예: 안녕하세요! 청년 정책 정보를 찾아드리는 챗 봇입니다!)

# 2단계) 간단한 규칙 기반 추출(Fast Path)
# 대상 : 키워드나 숫자가 명확히 드러나는 질문(예: 30살 일자리 정책)
# 처리 : 규칙 기반 함수 등을 통해 즉시 filter 생성 후 벡터 DB 쿼리.

# 3단계) LLM 호출(Fallback)
# 대상 : 복잡한 자연어 질문
# 처리 : LLM을 호출하여 의도를 파악하고 JSON으로 구조화된 정보 추출. 이를 기반으로 한 filter 생성 후 쿼리
# (질의 분석, 화행 분류, 질의 정제, NL2SQL 등의 과정..)

# 2단계는 생략하고 1, 3단계만 사용하자.

# %%
import os
import json
from openai import OpenAI

# %%
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
# 1단계 : 사전 차단
def is_policy_related_query(query: str) -> bool:
    """
    사용자 질문이 정책 추천 도메인과 관련이 있는지 규칙 기반으로 판단합니다.
    (1단계: Guardrail)
    """
    # 긍정 키워드: 이 단어들이 포함되면 관련 질문으로 간주
    policy_keywords = [
        '정책', '지원', '혜택', '대출', '주거', '일자리', '금융', '교육',
        '청년', '신청', '자격', '소득', '보증금', '월세', '취업', '창업'
    ]
    
    # 부정 키워드: 이 단어들이 포함되면 관련 없는 질문으로 간주
    unrelated_keywords = [
        '날씨', '맛집', '노래', '영화', '드라마', '안녕', '반가워', 'ㅎㅇ',
        '사랑', '여행', '게임', '스포츠'
    ]

    query_lower = query.lower()

    # 부정 키워드가 하나라도 있으면 즉시 False 반환
    if any(keyword in query_lower for keyword in unrelated_keywords):
        return False

    # 긍정 키워드가 하나라도 있으면 True 반환
    if any(keyword in query_lower for keyword in policy_keywords):
        return True
        
    # 위 두 조건에 모두 해당하지 않으면, 관련 없는 것으로 간주 (보수적 접근)
    return False

# %%
# 2단계 : 상세 정보 추출
def extract_structured_data_with_llm(query: str) -> dict:
    from datetime import datetime
    current_date_int = int(datetime.now().strftime('%Y%m%d'))
    
    system_prompt = f"""
    당신은 대한민국 청년 정책에 대한 사용자 질문을 분석하여, Chroma 데이터베이스 검색 필터로 사용할 JSON을 생성하는 AI 어시스턴트입니다.
    
    # 기본 원칙:
    - 사용자가 기간을 명시하지 않으면, 반드시 '현재 신청 가능한' 정책을 찾는 것을 기본값으로 삼아야 합니다.
    - 이를 위해, 현재 날짜({current_date_int})를 기준으로 `start_date_int`와 `end_date_int`를 비교하는 필터를 생성해야 합니다.
    - **중요**: Chroma는 최상위 레벨에 정확히 하나의 연산자만 허용하므로, 모든 조건을 `$and` 배열로 감싸야 합니다.
    
    # 지침:
    1. 사용자의 질문을 분석하여 필드 정보를 추출하세요.
    
    2. **필터 구조**: 모든 필터는 반드시 다음과 같은 구조를 따라야 합니다:
       {{"$and": [조건1, 조건2, ...]}}
    
    3. **기본 날짜 필터**: 사용자가 기간을 특정하지 않은 모든 경우, 아래 조건들을 **반드시 포함**하세요:
       {{"start_date_int": {{"$lte": {current_date_int}}}}},
       {{"end_date_int": {{"$gte": {current_date_int}}}}}
    
    4. **나이 필터**: 
       - 특정 나이 범위(예: "20대")를 언급하면, 해당 범위의 정책을 찾기 위해:
         {{"min_age": {{"$lte": 최대연령}}}},  // 정책의 최소 나이가 사용자 최대 나이보다 작거나 같음
         {{"max_age": {{"$gte": 최소연령}}}}   // 정책의 최대 나이가 사용자 최소 나이보다 크거나 같음
       - 예: 20대 → min_age <= 29, max_age >= 20
    
    5. **카테고리 필터**:
       - 단순 일치: {{"category_large": "주거"}}
       - 연산자 사용: {{"category_large": {{"$eq": "주거"}}}}
    
    6. **예외 처리**: 사용자가 '과거', '작년', '모든' 등 기간 제한 없이 검색하길 명시적으로 원하면, 날짜 필터를 포함하지 마세요.
    
    7. 추가 설명 없이 오직 JSON 객체만 응답해야 합니다.
    
    # 최종 출력 JSON 예시:
    
    ## 예시 1: "20대 주거 정책 찾아줘" (기본 필터링 적용)
    {{
        "$and": [
            {{"min_age": {{"$lte": 29}}}},
            {{"max_age": {{"$gte": 20}}}},
            {{"category_large": "주거"}},
            {{"start_date_int": {{"$lte": {current_date_int}}}}},
            {{"end_date_int": {{"$gte": {current_date_int}}}}}
        ]
    }}
    
    ## 예시 2: "현재 신청 가능한 청년 정책" (카테고리 없이)
    {{
        "$and": [
            {{"start_date_int": {{"$lte": {current_date_int}}}}},
            {{"end_date_int": {{"$gte": {current_date_int}}}}}
        ]
    }}
    
    ## 예시 3: "작년에 했던 모든 정책 알려줘" (기간 제한 없음)
    {{}}
    
    ## 예시 4: "25살이 받을 수 있는 교육 지원"
    {{
        "$and": [
            {{"min_age": {{"$lte": 25}}}},
            {{"max_age": {{"$gte": 25}}}},
            {{"category_large": "교육"}},
            {{"start_date_int": {{"$lte": {current_date_int}}}}},
            {{"end_date_int": {{"$gte": {current_date_int}}}}}
        ]
    }}
    """
    
    try:
        response = client.chat.completions.create(
            model="gpt-4o",  # gpt-4o 또는 gpt-4o-mini 추천
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": query}
            ],
            temperature=0,
            response_format={"type": "json_object"}
        )
        return json.loads(response.choices[0].message.content)
    except Exception as e:
        print(f"LLM 호출 중 오류 발생: {e}")
        return {"error": str(e)}

# %%
# 최종 지휘자(Orchestrator) 함수
def process_query_hybrid(query: str):
    """하이브리드 방식으로 사용자 질문을 처리하여 최종 ChromaDB 필터를 생성합니다."""
    print(f"입력 질문: \"{query}\"")
    
    if not is_policy_related_query(query):
        print("-> [처리 결과: 규칙 기반 차단]")
        return "정책과 관련된 질문을 해주세요."
    
    print("-> [처리 방식: LLM 호출하여 구조화된 데이터 추출]")
    structured_data = extract_structured_data_with_llm(query)
    print(f"   - LLM 추출 결과 (JSON): {structured_data}")
    return structured_data

# %%
print("--- Case 1: 관련 없는 질문 ---")
final_filter1 = process_query_hybrid("오늘 서울 날씨 어때?")

print("--- Case 2: 단일 나이 + 카테고리 질문 ---")
final_filter2 = process_query_hybrid("서른 살인데, 받을 수 있는 주거 정책이 궁금해")

print("--- Case 3: 나이 범위 + 담당부처 질문 ---")
final_filter3 = process_query_hybrid("20대를 위한 고용노동부 일자리 정책 좀 찾아줘")

print("--- Case 4: 정보는 없지만 관련 있는 질문 ---")
final_filter4 = process_query_hybrid("청년들을 위한 지원 정책에는 어떤 종류가 있나요?")
# Out:
# --- Case 1: 관련 없는 질문 ---
# 입력 질문: "오늘 서울 날씨 어때?"
# -> [처리 결과: 규칙 기반 차단]
# --- Case 2: 단일 나이 + 카테고리 질문 ---
# 입력 질문: "서른 살인데, 받을 수 있는 주거 정책이 궁금해"
# -> [처리 방식: LLM 호출하여 구조화된 데이터 추출]
#    - LLM 추출 결과 (JSON): {'$and': [{'min_age': {'$lte': 30}}, {'max_age': {'$gte': 30}}, {'category_large': '주거'}, {'start_date_int': {'$lte': 20250721}}, {'end_date_int': {'$gte': 20250721}}]}
# --- Case 3: 나이 범위 + 담당부처 질문 ---
# 입력 질문: "20대를 위한 고용노동부 일자리 정책 좀 찾아줘"
# -> [처리 방식: LLM 호출하여 구조화된 데이터 추출]
#    - LLM 추출 결과 (JSON): {'$and': [{'min_age': {'$lte': 29}}, {'max_age': {'$gte': 20}}, {'category_large': '일자리'}, {'organization': '고용노동부'}, {'start_date_int': {'$lte': 20250721}}, {'end_date_int': {'$gte': 20250721}}]}
# --- Case 4: 정보는 없지만 관련 있는 질문 ---
# 입력 질문: "청년들을 위한 지원 정책에는 어떤 종류가 있나요?"
# -> [처리 방식: LLM 호출하여 구조화된 데이터 추출]
#    - LLM 추출 결과 (JSON): {'$and': [{'start_date_int': {'$lte': 20250721}}, {'end_date_int': {'$gte': 20250721}}]}

# %%
# # 리트리버 기본 세팅
# retriever = vectorstore.as_retriever(
#     search_type="mmr",
#     search_kwargs={'k':5}
# )

# %%
user_query = "20대 청년이 받을 수 있는 정책이 궁금해"

# %%
ff = process_query_hybrid(user_query)
# Out:
# 입력 질문: "20대 청년이 받을 수 있는 정책이 궁금해"
# -> [처리 방식: LLM 호출하여 구조화된 데이터 추출]
#    - LLM 추출 결과 (JSON): {'$and': [{'min_age': {'$lte': 29}}, {'max_age': {'$gte': 20}}, {'start_date_int': {'$lte': 20250722}}, {'end_date_int': {'$gte': 20250722}}]}

# %%
# retrieved_docs = retriever.invoke(
#     user_query,
#     search_kwargs={'filter': ff}
# )
# # 필터링이 참 어렵구나.. 로직의 발상 자체에는 문제가 없어도.. 데이터 자체에 문제가 있는 경우가 많아서 ㅠㅠ

# 테스트 필터링
# ff = {
#     "$and": [
#         {"min_age": {"$lte": 20}},  # 주의: 연산자 위치 수정
#         {"max_age": {"$gte": 29}},  # 주의: 연산자 위치 수정
#         {"category_large": {"$eq": "주거"}},
#         {"start_date_int": {"$lte": 20250721}},
#         {"end_date_int": {"$gte": 20250721}}
#     ]
# }

# %%
# 리트리버 대신 벡터 스토어의 유사도 검색 메서드를 직접 호출
retrieved_docs = vectorstore.similarity_search(
    user_query,
    k=20,
    filter=ff
)

# %%
print(len(retrieved_docs))
for i in retrieved_docs:
    print(i.metadata['start_date_int'])
    print(i.metadata['end_date_int'])
    # print(i)
    print('-'*20)
# Out:
# 20
# 20250101
# 20250930
# --------------------
# 20250101
# 20251215
# --------------------
# 20250210
# 20251130
# --------------------
# 20250101
# 20251210
# --------------------
# 20250203
# 20251204
# --------------------
# 20250421
# 20251231
# --------------------
# 20250203
# 20251204
# --------------------
# 20250101
# 20251231
# --------------------
# 20250320
# 20251120
# --------------------
# 20250701
# 20250731
# --------------------
# 20250213
# 20251231
# --------------------
# 20250203
# 20251128
# --------------------
# 20250701
# 20250731
# --------------------
# 20250101
# 20251231
# --------------------
# 20250304
# 20251231
# --------------------
# 20250207
# 20251130
# --------------------
# 20250101
# 20251222
# --------------------
# 20250101
# 20251231
# --------------------
# 20250203
# 20251128
# --------------------
# 20250301
# 20251130
# --------------------

# %%
# 리트리버로도 작동 되나 다시 테스트
# 리트리버 기본 세팅
retriever = vectorstore.as_retriever(
    search_type="mmr",
    search_kwargs={'k':10}
)

# %%
retrieved_docs = retriever.invoke(
    user_query,
    search_kwargs={'filter': ff}
)

# %%
print(len(retrieved_docs))
for i in retrieved_docs:
    # print(i.metadata['start_date_int'])
    # print(i.metadata['end_date_int'])
    print(i)
    print('-'*20)
# Out:
# 10
# page_content='정책명: 2024 미래내일 청년일경험 참여청년 모집(사무행정 6차)
# 정책 설명: -
# 지원 내용: -
# 신청 자격: -' metadata={'policy_name': '2024 미래내일 청년일경험 참여청년 모집(사무행정 6차)', 'category_medium': '재직자', 'category_large': '일자리', 'start_date_int': 20241022, 'end_date_int': 20241028, 'main_department': '베스트인', 'application_period_str': '20241022 ~ 20241028', 'operating_department': '베스트인'}
# --------------------
# page_content='정책명: 국방부 2030자문단 공개 모집
# 정책 설명: 정책 수립과 집행 과정에서 청년세대의 인식을 전달하는 임무를 수행할 '2030 자문단' 단원 공개 모집
# 지원 내용: □ 활동혜택 : 회의 참석 시 수당 등 지급, 국방부장관 명의 위촉장 수여
# □ 활동방법 : 분기당 1회 대면 회의/월 1~2회 비대면 영상 회의
# □ 주요임무
#  ○ 국방 분야 청년정책 모니터링
#  ○ 국방 분야 관련 청년 의견 수렴 및 전달
#  ○ 국방 분야 청년정책 개선과제 발굴 및 제언 등
#    ※ 국방 분야 : 진로·취업지원, 병영생활, 자기계발, 복지·문화
# □ 활동 계획
#  ○ 발대식 : 2024년 3월 中    *위촉장 수여 및 기념사진 촬영
#  ○ 활동내용 : 분기 1회 대면 회의, 월 1~2회 비대면 회의
#     - 분과별 대면 회의 후 의견 종합하여 청년보좌역 주관 종합 회의 참석
#     - 회의 참석 시 수당 등 지급
#     - 인터넷 활용 가능한 장소에서 화상회의 프로그램 활용 회의 진행 예정
#  ○ 활동 종료 시 “2030 자문단 활동 증명서” 발급
# 신청 자격: 나이는 면접 월 기준으로 계산(1985년 1월생~2005년 1월생)
#  ※ 군 복무 경험 불필요 및 자격 제한이 없으므로 많은 지원 바랍니다.
#  ※ 현역 장병(병, 초급간부) 지원 가능하며, 소속 부대에 공가 부여 협조 문서 발송 예정' metadata={'category_medium': '청년참여,정책인프라구축', 'start_date_int': 20231229, 'policy_name': '국방부 2030자문단 공개 모집', 'category_large': '참여권리,참여권리', 'end_date_int': 20240110, 'main_department': '국방부', 'min_age': 19, 'operating_department': '국방부', 'max_age': 39, 'application_period_str': '20231229 ~ 20240110'}
# --------------------
# page_content='정책명: 성동형 청년 등 탈모 치료 지원 사업
# 정책 설명: 39세 이하 청년 등 구민에게 탈모 치료비를 지원하는 사업
# 지원 내용: 경구용 약제비에 한정하여 지원（본인 구매금액의 80%씩）, 1인당 연간 20만 원 한도
# 신청 자격: ** 2023년 지원대상자도 2024년 1월 이후 발급된 진단서（또는 소견서, 병명코드 必） 제출 필수' metadata={'max_age': 39, 'application_period_str': '20240205 ~ 20241129', 'category_medium': '건강', 'policy_name': '성동형 청년 등 탈모 치료 지원 사업', 'operating_department': '주관기관 동일', 'start_date_int': 20240205, 'category_large': '복지문화', 'min_age': 0, 'end_date_int': 20241129, 'main_department': '성동구청 아동청년과'}
# --------------------
# page_content='정책명: 청년통계 개선
# 정책 설명: 청년고용촉진특별법 상 연령규정 개정(15-29세 → 15-34세)에 맞춰 고용동향 공표 시 고용률, 실업률 등 추가 통계 발표 추진
# 지원 내용: 청년고용촉진특별법 상 연령규정 개정(15-29세 → 15-34세)에 맞춰 고용동향 공표 시 고용률, 실업률 등 추가 통계 발표를 추진하고, 청년층 통계 작성 및 정책 수립을 지원하기 위해 청년층통계등록부를 구축 및 통계데이터센터를 통해 제공하며, 청년층 행정통계를 작성하여 증거기반 정책수립을 지원하고자 함
# 신청 자격:' metadata={'min_age': 0, 'category_large': '참여권리', 'max_age': 0, 'main_department': '통계청', 'category_medium': '정책인프라구축', 'policy_name': '청년통계 개선'}
# --------------------
# page_content='정책명: 대구형 청년 그린 내일채움공제
# 정책 설명: 청년에게 자산 형성의 기회를 제공하여 지역 정착을 유도하고 지역기업의 고용 안정화를 지원
# 지원 내용: 월 34만원(대구시10·청년10·기업14)을 5년간 적립하여 최종 만기 시 청년에게 목돈 2,040만원 + 복리이자 지급
# 신청 자격: 2024년부터 신규모집 종료' metadata={'operating_department': '대구지역본부', 'category_medium': '재직자', 'max_age': 34, 'category_large': '일자리', 'policy_name': '대구형 청년 그린 내일채움공제', 'min_age': 15, 'main_department': '고용노동정책과'}
# --------------------
# page_content='정책명: 청년 국가기술자격시험 응시료 지원사업
# 정책 설명: 청년의 구직활동과 경력개발의 경제적 부담을 완화하기 위한 사업
# 지원 내용: - 34세 이하 청년을 대상(소득 및 취업 여부 무관)으로 한국산업인력공단이 시행하는 국가기술자격 시험(‘25년 기준 488종목)에 응시하는 경우 응시료의 50%를 선 지원
# - 1인당 총 3회 지원으로 제한하고, 지원금 소진 시까지 한정
# 신청 자격: 34세 이하 청년, 한국산업인력공단 시행 국가기술자격 종목, 1인당 연간 3회 한도' metadata={'category_medium': '취업', 'category_large': '일자리', 'policy_name': '청년 국가기술자격시험 응시료 지원사업', 'main_department': '고용노동부', 'max_age': 34, 'min_age': 0, 'operating_department': '한국산업인력공단'}
# --------------------
# page_content='정책명: 2024년 청년창업농 정책자금 이차보전 사업 신청 안내
# 정책 설명: -
# 지원 내용: □ `19년 이후 청년후계농으로 선정된 이후 실행한 정책자금(융자)의 거치기간에 해당되는 이자 중 0.5% 지원(최대 2.5백만원/연)
# ※ 고정금리, 변동금리 관계없이 지원, 매년 사업 신청을 받아 대상자를 선정하되, 최대 3년 지원
# 신청 자격: -' metadata={'main_department': '전북특별자치도 전주시', 'end_date_int': 20240131, 'operating_department': '전북특별자치도 전주시', 'policy_name': '2024년 청년창업농 정책자금 이차보전 사업 신청 안내', 'application_period_str': '20240115 ~ 20240131', 'category_large': '복지문화,일자리', 'category_medium': '취약계층 및 금융지원,창업', 'start_date_int': 20240115}
# --------------------
# page_content='정책명: 2024년 청년 하루 배움 Day (신박한 정리수납)
# 정책 설명: 원데이 클래스
# 지원 내용: □ 강의내용: 공간이 바뀌면 인생이 바뀐다 ‘신박한 정리수납’
# □ 강의장소: 울진청년일자리센터(울진읍 읍내로 57-6)
# □ 강의일시: 2024. 3. 13.(수) 14시
# 신청 자격: -' metadata={'category_large': '일자리,교육', 'start_date_int': 20240305, 'operating_department': '경상북도 울진군 관광경제국 일자리경제과', 'policy_name': '2024년 청년 하루 배움 Day (신박한 정리수납)', 'application_period_str': '20240305 ~ 20240311', 'main_department': '경상북도 울진군', 'max_age': 49, 'min_age': 19, 'category_medium': '취업,미래역량강화', 'end_date_int': 20240311}
# --------------------
# page_content='정책명: 청년희망적금
# 정책 설명: 사회진입 초기의 근로청년들에게 자산형성의 토대 마련
# 지원 내용: 120만 원(10만 원×12개월) 적립 및 지원조건 충족 시 120만 원 지원
# 신청 자격:' metadata={'operating_department': '대구광역시청년센터', 'end_date_int': 20240705, 'application_period_str': '20240617 ~ 20240705', 'category_medium': '취약계층 및 금융지원,문화활동', 'main_department': '대구광역시', 'max_age': 39, 'policy_name': '청년희망적금', 'min_age': 19, 'start_date_int': 20240617, 'category_large': '복지문화,복지문화'}
# --------------------
# page_content='정책명: 청년정책 제안 경연대회
# 정책 설명: 청년정책 수요 당사자인 청년들이 직접 청년정책을 발굴하여 청년의 정책 효능감 향상및 청년문제 해결을 위한 정책 참여 기회 제공
# 지원 내용: ○ 시 기 : '25. 4. ~ 6.
#
# ○ 참여대상 : 울산에 거주하거나 활동하는 19세 ~ 39세 청년
#
# ○ 주요내용 : 정책 컨설팅을 통한 내실 있는 청년제안 발굴
# -분과별 토론, 정책의제 도출 및 구체화, 집중 멘토링
# -컨설팅을 통한 분과별 정책제안서 검토·작성
#
# ○ 추진방법 : 제안서 접수 → 1차 심사 → 전문가 컨설팅 → 최종 심사
#  ※ 팀구성 : 10개팀 30명 정도(팀당 3명 정도)
# 신청 자격:' metadata={'min_age': 19, 'main_department': '울산광역시', 'category_medium': '청년참여', 'policy_name': '청년정책 제안 경연대회', 'max_age': 39, 'category_large': '참여권리'}
# --------------------

# %%
# 결과 : 적용 안 됨. 
# 리트리버로 구성 후 동적 필터링을 위해선..
# 1. 매 필터마다 동적으로 리트리버를 생성하거나(성능 문제에 대한 생각이 듦..)
# 2. configurableRetriever나 RunnableLambda 등을 사용해야 한다.
# => LCEL 공부의 필요성 ㅠ

# 일단 mvp니까.. 직접 호출하도록 구성하고, 후에 천천히 쌓아올리자.

# %%
# 흠.. 클로드 좀 때려본 결과 다른 필터를 적용한 리트리버를 생성(as_retriever())하는 것은 
# 오버헤드가 그렇게 크지 않을 것으로 예상된다고 한다..
# 결국 난 랭체인을 활용해야하고, 그러기 위해서는 LCEL을 써야하며 LCEL을 쓰려면 단순 유사도 검색이 아니라
# retriever가 필요하므로.. 다른 문제가 발생하지 않는 한, as_retriever()에 동적 필터를 전달하는 방식을 사용하자


# 생각해 볼 것 : search_type mmr Vs similarity

# %%
# 테스트

def get_filtered_retriever(filter_condition):
    return vectorstore.as_retriever(
        search_type="mmr",
        search_kwargs={"k":10, "fetch_k":30, "lambda_mult":0.7, "filter": filter_condition}
    )

r = get_filtered_retriever(ff)

# %%
d = r.invoke(user_query)

# %%
print(len(d))
for i in d:
    print(i.metadata['start_date_int'])
    print(i.metadata['end_date_int'])
    # print(i)
    print('-'*20)
# Out:
# 10
# 20250101
# 20250930
# --------------------
# 20250101
# 20251210
# --------------------
# 20250421
# 20251231
# --------------------
# 20250101
# 20251231
# --------------------
# 20250320
# 20251120
# --------------------
# 20250701
# 20250731
# --------------------
# 20250213
# 20251231
# --------------------
# 20250203
# 20251128
# --------------------
# 20250101
# 20251231
# --------------------
# 20250301
# 20251130
# --------------------
