# %%
# 이걸 잠시 하다보니 다른 생각이 든다..
# 필터링을 위한 메타데이터..가 존재해야하나? 벡터 db에서 필터링을 해야하나?
# 단순히 연산이 작아보이고 쉬워보여서.. 대충 메타데이터에 넣고, 벡터db에서 필터링 하게 한 게 잘못된 건 아닐까?
# 그냥 이러한 필터링 자체는 최대한 rdb 단에서 수행하고, 메타데이터와 벡터db의 사용을 최적화 하는 게 더 좋지 않을까?
# => 그렇게 하자. 처음부터 다시하자.

# %% [raw]
# 우리가 RDB로 관리할 필드는.. 특히 필터링과 관련된 필드들..
#
# plcyId : PK.
#
# A. 사용자 조건 필터
# - location : 거주지 정보(zipCd 변환 필요)
# - min_age / max_age : 지원 최소/최대 연령
# - job_status : 취업 상태(jobCd 변환 필요)
# - education_level : 학력 요건 (schoolCd 변환 필요)
# - major : 전공 요건(plcyMajorCd 변환 필요)
# - income_min / income_max : 소득 최소 최대.
#
# B. 정책 내용 기반 필터
# - category : 정책 대분류
# - category_sub : 중분류
# - keyword : 정책 키워드(예: 대출, 보조금) zipCd와 마찬가지로 정규화 필요
#
# C. 기간 및 상태 필터(Time/Status Filters)
# - biz_start_date / biz_end_date : 사업 시작일 / 종료일
# - aply_start_date / aply_end_date : 지원 시작일 / 종료일
# - aplyPrdSeCd : 상시인지 아닌지? 이거 필요한가.. 일단 적어

# %% [raw]
# 필드로 관리할 코드는..
# 신청기간구분코드(자연어 필드로 충분), 사업기간구분코드(자연어 필드로 충분), 결혼상태코드(자연어 필드로 충분), 소득 조건(자연어 필드로 충분)이고
#
# 테이블로 관리할 코드는..
# 정책전공요건코드(o), 정책취업요건코드(o), 정책학력요건코드(o), 정책특화 요건 코드(o), 정책 대분류(o), 정책 중분류(o), 정책 키워드(o).
#
# + 지역 코드(zip) (o)

# %%
def populate_code_tables(cursor):
    """
    엑셀 파일의 각 시트를 읽어 코드 테이블에 데이터를 삽입합니다.
    """
    print("🚀 코드 테이블 데이터 이관 시작...")

    try:
        # 테이블과 시트 이름, 그리고 해당 시트 내의 컬럼명을 매핑합니다.
        # 시트 이름은 실제 엑셀 파일의 시트 이름과 정확히 일치해야 합니다.
        code_sheets_map = {
            'major_codes': ('코드정보', 'plcyMajorCd', '코드', '코드내용'),
            'job_status_codes': ('코드정보', 'jobCd', '코드', '코드내용'),
            'education_level_codes': ('코드정보', 'schoolCd', '코드', '코드내용'),
            'specialization_codes': ('코드정보', 'sBizCd', '코드', '코드내용'),
            'category_codes': ('정책대분류', None, '번호', '정책대분류명(lclsfNm)'),
            'subcategory_codes': ('정책중분류', None, '번호', '정책중분류명(mclsfNm)'),
            'keywords': ('정책키워드', None, None, '정책키워드명(plcyKywdNm)')
        }
        
        for table_name, (sheet_name, filter_col, code_col, name_col) in code_sheets_map.items():
            print(f"  - 테이블 '{table_name}' 작업 중 (시트: '{sheet_name}')...")
            # read_excel을 사용하여 특정 시트를 읽어옵니다.
            df = pd.read_excel(excel_file_path, sheet_name=sheet_name)
            
            # '코드정보' 시트의 경우, 특정 분류(jobCd 등)로 필터링
            if filter_col:
                df = df[df['분류'] == filter_col].copy()
            
            insert_sql = ""
            # 각 테이블 구조에 맞게 데이터 준비 및 INSERT
            if table_name == 'keywords':
                insert_sql = f"INSERT INTO {table_name} (name) VALUES (%s)"
                data_to_insert = [(row[name_col],) for index, row in df.iterrows() if pd.notna(row[name_col])]
            else:
                insert_sql = f"INSERT INTO {table_name} (code, name) VALUES (%s, %s)"
                data_to_insert = [(str(row[code_col]), row[name_col]) for index, row in df.iterrows() if pd.notna(row[code_col]) and pd.notna(row[name_col])]
            
            cursor.executemany(insert_sql, data_to_insert)
            print(f"    ✅ {cursor.rowcount}개 행 삽입 완료.")

    except FileNotFoundError:
        print(f"🚨 오류: 엑셀 파일('{excel_file_path}')을 찾을 수 없습니다. 파일 이름과 경로를 확인하세요.")
        raise
    except Exception as e:
        print(f"🚨 오류: 코드 테이블 이관 중 문제 발생 - {e}")
        raise

# %%
db_config = {
    'host': 'localhost',
    'user': 'root',
    'password': '1234',
    'database': 'toyprj4'
}

# 엑셀 파일 이름 (사용자님이 변경하신 이름)
excel_file_path = './code_table.xlsx'

# %%
connection = None
connection = mysql.connector.connect(**db_config)
cursor = connection.cursor()
print("✅ 데이터베이스 연결 성공!")

populate_code_tables(cursor)
# Out:
# ✅ 데이터베이스 연결 성공!
# 🚀 코드 테이블 데이터 이관 시작...
#   - 테이블 'major_codes' 작업 중 (시트: '코드정보')...
#     ✅ 1개 행 삽입 완료.
#   - 테이블 'job_status_codes' 작업 중 (시트: '코드정보')...
#     ✅ 1개 행 삽입 완료.
#   - 테이블 'education_level_codes' 작업 중 (시트: '코드정보')...
#     ✅ 1개 행 삽입 완료.
#   - 테이블 'specialization_codes' 작업 중 (시트: '코드정보')...
#     ✅ 1개 행 삽입 완료.
#   - 테이블 'category_codes' 작업 중 (시트: '정책대분류')...
#     ✅ 5개 행 삽입 완료.
#   - 테이블 'subcategory_codes' 작업 중 (시트: '정책중분류')...
#     ✅ 17개 행 삽입 완료.
#   - 테이블 'keywords' 작업 중 (시트: '정책키워드')...
#     ✅ 17개 행 삽입 완료.

# %%
connection.commit()
print("\n🎉 모든 작업이 성공적으로 완료되었습니다.")
# Out:
# 🎉 모든 작업이 성공적으로 완료되었습니다.

# %%
# connection.rollback()

# %% [raw]
# 잘 되었는지 확인하기
# 중분류 o 정책특화 o
# 키워드 o 대분류 o
#
# 나머진 그냥 수동으로 삽입하자. 어차피 많지도 않고..
#
# 정책 데이터 이관이나 고민할 것
# (내일 할거)
# 대충 생각하기론.. 여기서 pandas 사용해서 필요한 필드만 우선 추출
# 변환 필요한 필드들 가공
# csv(또는 json)로 만든 뒤 db에 삽입.

# %% [raw]
# 아.. 다시해야한다..
# 그냥 직접 쓰자 하..
#
# 일단 코드 테이블은 다 만들었는데..
# 매핑 테이블이 얼마나 필요한지 다시 생각해보자..
# 몇몇개는 필드로 들어가도 되지만.. 다른 몇몇개는 매핑으로 풀어야 한다..
# 데이터 좀 확인해보자..
#
# 학력 제한 코드 => 코드,2개 이상인 경우 존재 => 코드 테이블, 매핑 테이블
# 직업 코드 => 코드. 2개 이상인 경우 존재 => 코드 테이블, 매핑 테이블
# 전공 코드 => 코드, 2개 이상인 경우 존재 => 코드 테이블, 매핑 태이블
# 특화 코드 => 코드, 2개 이상인 경우 존재 => 코드 테이블, 매핑 테이블
#
#
# 지역 코드 => 상당히 다수에 5자. 3자로 분리 및 코드 테이블, 매핑 테이블
#
# 정책 대분류/정책 중분류 => 2개 이상 있는 경우 확인 완료. 특히 코드로 된 게 아니고 자연어로 되어있음
# => 코드 테이블 삭제, only 매핑 테이블만.. 매핑 테이블에 자연어로 작성.
#
# 정책 키워드 명 => 마찬가지로 자연어 테이블.. 2개 이상 있는 경우 있으니 매핑 테이블만 사용하자.
#
# ---
# 구분자는 ','
#
#
# 결혼 상태는..
#
# 내일 오면 이관작업 계쏙 하자..

# %%
# 1. 데이터 불러오기

import pandas as pd
import numpy as np

# 데이터가 담긴 CSV 파일 경로
csv_file_path = './policy_data.csv' # 실제 파일 이름으로 변경해주세요.

try:
    # CSV 파일을 DataFrame으로 읽어옵니다.
    # 한글 깨짐 방지를 위해 encoding='utf-8'을 사용합니다.
    df_raw = pd.read_csv(csv_file_path, encoding='utf-8')
    
    # 데이터 로딩 성공 확인
    print("✅ 1단계 성공: 데이터 로딩 완료!")
    print(f"전체 정책 데이터 수: {len(df_raw)}개")
    
    # 데이터 구조 확인을 위해 상위 3개 행을 출력합니다.
    print("\n--- 원본 데이터 샘플 ---")
    print(df_raw.head(3))
    
except FileNotFoundError:
    print(f"❌ 오류: '{csv_file_path}' 파일을 찾을 수 없습니다. 파일 경로를 확인해주세요.")
except Exception as e:
    print(f"❌ 오류: 파일을 읽는 중 문제가 발생했습니다. (오류: {e})")
# Out:
# ✅ 1단계 성공: 데이터 로딩 완료!
# 전체 정책 데이터 수: 3861개
#
# --- 원본 데이터 샘플 ---
#                  plcyNo  bscPlanCycl  bscPlanPlcyWayNo  bscPlanFcsAsmtNo  \
# 0  20250717005400211359            1                 4                16
# 1  20250717005400211358            1                 4                16
# 2  20250717005400211357            1                 4                16
#
#    bscPlanAsmtNo  pvsnInstGroupCd  plcyPvsnMthdCd  plcyAprvSttsCd  \
# 0             41            54002         42002.0           44002
# 1             43            54002         42004.0           44002
# 2             43            54002         42004.0           44002
#
#                    plcyNm           plcyKywdNm  ... rgtrHghrkInstCd  \
# 0        웹툰캠퍼스 운영 및 인력 양성  교육지원,인턴,맞춤형상담서비스,벤처  ...         6270000
# 1               학예사 인턴 운영                   인턴  ...         6540000
# 2  전북청년 2025 (전북청년 미술 운영)                  보조금  ...         6540000
#
#   rgtrHghrkInstCdNm                                              zipCd  \
# 0             대구광역시  27110,27140,27170,27200,27230,27260,27290,2771...
# 1           전북특별자치도  11110,11140,11170,11200,11215,11230,11260,1129...
# 2           전북특별자치도  52111,52113,52130,52140,52180,52190,52210,5271...
#
#   plcyMajorCd    jobCd                 schoolCd              aplyYmd  \
# 0     0011009  0013010                  0049010  20250501 ~ 20250530
# 1     0011006  0013003  0049007,0049008,0049009                  NaN
# 2     0011009  0013010                  0049010  20241007 ~ 20241018
#
#              frstRegDt          lastMdfcnDt           sbizCd
# 0  2025-07-17 16:00:49  2025-07-17 17:18:02          0014010
# 1  2025-07-17 14:38:21  2025-07-17 14:56:21  0014008,0014009
# 2  2025-07-17 14:32:05  2025-07-17 15:56:14          0014010
#
# [3 rows x 60 columns]

# %%
# 2. 데이터 정제 및 가공
# 숫자 형 변환 : 나이, 소득 등 숫자여야 하는 열들의 데이터 타입을 숫자로 확실하게 변환, 숫자로 변환 불가한 경우 NaN 처리
# 날짜 형 변환 : yymmdd 형식의 날짜륻릉ㄹ 실제 날짜 형으로 변환하고, 구간 정보의 경우 분리.

# --- 2.1. 필요한 컬럼 선택 및 이름 변경 ---

# DB 스키마와 매핑할 컬럼 정의: { '원본 CSV 컬럼명': '새로운 중간 컬럼명' }
column_mapping = {
    'plcyNo': 'policy_id',
    'plcyNm': 'policy_name',
    'plcyExplnCn': 'policy_summary',
    'refUrlAddr1': 'source_url',
    'sprtTrgtMinAge': 'min_age',
    'sprtTrgtMaxAge': 'max_age',
    'earnMinAmt': 'income_min',
    'earnMaxAmt': 'income_max',
    'bizPrdBgngYmd': 'biz_start_date',
    'bizPrdEndYmd': 'biz_end_date',
    'aplyYmd': 'aply_period',           # 신청기간 (나중에 분리)
    'mrgSttsCd': 'marriage_status',     # 결혼상태 코드 (단일 값으로 가정)
    'jobCd': 'job_status_codes',        # 취업상태 코드 (다중 값 가능)
    'schoolCd': 'education_level_codes',# 학력 코드 (다중 값 가능)
    'plcyMajorCd': 'major_codes',       # 전공 코드 (다중 값 가능)
    'plcyKywdNm': 'keywords',           # 키워드 (다중 값 가능)
    'zipCd': 'region_codes',            # 지역 코드 (다중 값 가능)
    'lclsfNm': 'category_names',        # 카테고리 이름 (다중 값 가능)
    'mclsfNm': 'subcategory_names'      # 서브카테고리 이름 (다중 값 가능)
}

# 원본 데이터에서 필요한 컬럼만 선택
df_selected = df_raw[list(column_mapping.keys())].copy()

# 컬럼 이름 변경
df_processed = df_selected.rename(columns=column_mapping)


# --- 2.2. 숫자 형식 변환 ---

numeric_cols = ['min_age', 'max_age', 'income_min', 'income_max']
for col in numeric_cols:
    # 숫자로 변환, 변환 불가 값은 결측치(NaN)로 처리
    df_processed[col] = pd.to_numeric(df_processed[col], errors='coerce')
    # API에서 '0'은 '제한 없음'을 의미하는 경우가 많으므로, 분석을 위해 결측치로 변경
    df_processed[col] = df_processed[col].replace(0, np.nan)


# --- 2.3. 날짜 형식 변환 ---

def to_datetime_safe(date_str):
    """YYYYMMDD 형식의 문자열을 datetime 객체로 안전하게 변환합니다."""
    if pd.isna(date_str) or not isinstance(date_str, str) or not date_str.strip():
        return pd.NaT # 비어있거나 문자열이 아니면 날짜 결측치(NaT) 반환
    return pd.to_datetime(date_str, format='%Y%m%d', errors='coerce')

def parse_apply_period(period_str):
    """'YYYYMMDD ~ YYYYMMDD' 형식에서 시작일과 종료일을 분리합니다."""
    if pd.isna(period_str) or '~' not in str(period_str):
        return pd.NaT, pd.NaT
    try:
        start_str, end_str = [s.strip() for s in period_str.split('~')]
        return to_datetime_safe(start_str), to_datetime_safe(end_str)
    except ValueError:
        return pd.NaT, pd.NaT

# %%
# Out:
# ✅ 컬럼 선택 및 이름 변경 완료!
#
# --- 변환 후 컬럼 목록 ---
# ['policy_id', 'policy_name', 'policy_summary', 'source_url', 'min_age', 'max_age', 'income_min', 'income_max', 'biz_start_date', 'biz_end_date', 'marriage_status_code', 'job_status_code', 'education_level_code', 'major_code', 'category_name', 'subcategory_name', 'zip_code', 'aply_period', 'keywords']
#
# --- 변환 후 데이터 샘플 (상위 5개) ---
#               policy_id             policy_name  \
# 0  20250717005400211359        웹툰캠퍼스 운영 및 인력 양성
# 1  20250717005400211358               학예사 인턴 운영
# 2  20250717005400211357  전북청년 2025 (전북청년 미술 운영)
# 3  20250717005400211356       제주특별자치도 공공기관 통합채용
# 4  20250717005400211355  제3차 대구광역시 청년정책 기본계획 수립
#
#                                       policy_summary  \
# 0  - 현장 실무형 전문인력 프로그램을 통한 글로벌 웹툰작가 양성\n- 웹툰 창작 및 ...
# 1                  도내 전문 학예인력 양성 및 시각예술 분야 청년 일자리 창출
# 2  전북 청년미술가의 안정적 창작활동을 위한 환경제공 및 역량 강화를 위한 전문가들과의...
# 3  ❍ 제주도 내 공공기관 채용과정의 공정성·투명성 확보 및 도민 신뢰 제고를 위해 공...
# 4  지역 청년의 삶 전반을 고려한 중장기 전략인「제3차 대구광역시 청년정책 기본계획」수...
#
#                                          source_url  min_age  max_age  \
# 0                                               NaN      NaN      NaN
# 1                                               NaN     18.0     39.0
# 2                                               NaN     18.0     39.0
# 3  https://www.jeju.go.kr/works/exam/exam3/list.htm      NaN      NaN
# 4                                               NaN     19.0     39.0
#
#    income_min  income_max biz_start_date biz_end_date  marriage_status_code  \
# 0         NaN         NaN       20250501     20251231               55003.0
# 1         NaN         NaN       20250101     20251231               55003.0
# 2         NaN         NaN       20250101     20251231               55003.0
# 3         NaN         NaN                                           55003.0
# 4         NaN         NaN       20250318     20251212               55003.0
#
#   job_status_code     education_level_code major_code category_name  \
# 0         0013010                  0049010    0011009          복지문화
# 1         0013003  0049007,0049008,0049009    0011006          복지문화
# 2         0013010                  0049010    0011009          복지문화
# 3         0013010                  0049010    0011009           일자리
# 4         0013010                  0049010    0011009          참여권리
#
#   subcategory_name                                           zip_code  \
# 0            예술인지원  27110,27140,27170,27200,27230,27260,27290,2771...
# 1            예술인지원  11110,11140,11170,11200,11215,11230,11260,1129...
# 2            예술인지원  52111,52113,52130,52140,52180,52190,52210,5271...
# 3               취업                                        50110,50130
# 4          정책인프라구축  27110,27140,27170,27200,27230,27260,27290,2771...
#
#            aply_period             keywords
# 0  20250501 ~ 20250530  교육지원,인턴,맞춤형상담서비스,벤처
# 1                  NaN                   인턴
# 2  20241007 ~ 20241018                  보조금
# 3                  NaN              장기미취업청년
# 4                  NaN                 교육지원
#
# --- 숫자 컬럼 정보 요약 ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3861 entries, 0 to 3860
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   min_age     2436 non-null   float64
#  1   max_age     2454 non-null   float64
#  2   income_min  1 non-null      float64
#  3   income_max  7 non-null      float64
# dtypes: float64(4)
# memory usage: 120.8 KB
# None

# %%
# Out:
# ✅ 날짜 데이터 처리 완료!
#
# --- 날짜 컬럼 정보 ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3861 entries, 0 to 3860
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   biz_start_date   795 non-null    datetime64[ns]
#  1   biz_end_date     796 non-null    datetime64[ns]
#  2   aply_start_date  2475 non-null   datetime64[ns]
#  3   aply_end_date    2475 non-null   datetime64[ns]
# dtypes: datetime64[ns](4)
# memory usage: 120.8 KB
# None
#
# --- 날짜 변환 후 데이터 샘플 (상위 5개) ---
#   biz_start_date biz_end_date aply_start_date aply_end_date
# 0     2025-05-01   2025-12-31      2025-05-01    2025-05-30
# 1     2025-01-01   2025-12-31             NaT           NaT
# 2     2025-01-01   2025-12-31      2024-10-07    2024-10-18
# 3            NaT          NaT             NaT           NaT
# 4     2025-03-18   2025-12-12             NaT           NaT
